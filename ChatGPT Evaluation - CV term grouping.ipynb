# %%
# generate term groupings but chunk it up and loop it to create several jsons

# %%
# Import the os package
import os

# Import the openai package
import openai

import os
import openai
from scipy.spatial import distance
import plotly.express as px
from sklearn.cluster import KMeans
import json
import re

# %%
from dotenv import load_dotenv

# Load environment variables from .env file
load_dotenv()

# Access the OpenAI API key
openai.api_key = os.getenv("OPENAI_API_KEY")

# %%
import pandas as pd

concepts_syn_df = pd.read_csv("concept_synonyms_CVsubset.csv")
concepts_syn_df.head()
# Out:
#        general_ancestor_concept_name  general_ancestor_concept_id  \
# 0  Disorder of cardiovascular system                       134057
# 1  Disorder of cardiovascular system                       134057
# 2  Disorder of cardiovascular system                       134057
# 3  Disorder of cardiovascular system                       134057
# 4  Disorder of cardiovascular system                       134057
#
#    descendant_concept_id        concept_name        rc  dbc         drc  ddbc  \
# 0                 443784   Vascular disorder    186458   13  1408753835    22
# 1                 443784   Vascular disorder    186458   13  1408753835    22
# 2                 443784   Vascular disorder    186458   13  1408753835    22
# 3                 443784   Vascular disorder    186458   13  1408753835    22
# 4               44784217  Cardiac arrhythmia  84417590   19   809155077    22
#
#    max_levels_of_separation  concept_id                 concept_synonym_name
# 0                         1      443784                           Angiopathy
# 1                         1      443784             Disorder of blood vessel
# 2                         1      443784                     Vascular disease
# 3                         1      443784  Disorder of blood vessel (disorder)
# 4                         2    44784217                           Arrhythmia

# %% [markdown]
# # GPT Term Grouping Task Start

# %%
import openai

# Function to split a long list into smaller chunks
def chunk_list(lst, chunk_size=50):
    for i in range(0, len(lst), chunk_size):
        yield lst[i:i + chunk_size]

def generate_term_grouping(term_list, ancestor_list):
    # Define chunk size (e.g., 500 terms per batch)
    chunk_size = 50

    # Initialize a list to store all the responses
    all_responses = []

    # Iterate through the term list in chunks
    for chunk in chunk_list(term_list, chunk_size):
        # Convert chunk to string for prompt
        chunk_str = ", ".join(chunk)

        # Construct the prompt for the current chunk
        prompt = f"""Please group these terms: {chunk_str} into these categories: {ancestor_list}
        
        use all terms that is provided, and only place them in categories that are provided.
        If there is a term that does not belong, you can put it in a category called "other". 
        No category should have no terms. (ie. do not allow empty categories.)
        
        output only the json object.
        
        Please break your JSON output into smaller, manageable chunks as needed. Each chunk should represent a logical portion of the grouping. 
    Indicate which part of the hierarchy you're returning by including the part number, for example: 
    [start chunk 1/5] ```json ...  ``` [end chunk 1/5]
    
        """

        # Call the API for each chunk
        response = openai.chat.completions.create(
            model="gpt-4o",
            messages=[
                {
                    "role": "system", 
                    "content": """Organize a list of cardiovascular diseases and conditions into meaningful groupings based on how medically similar they are.

# Steps

1. **List Cardiovascular Conditions**: Review the provided list of medical terms.

2. **Categorize Conditions**: Group these conditions based on their medical similarities, such as:
   - **Heart Diseases**: Conditions specifically related to heart function.
   - **Vascular Diseases**: Conditions affecting blood vessels.
   - **Congenital Conditions**: Heart or vessel conditions present at birth.
   - **Arrhythmias**: Disorders of heart rhythm.

3. **Refine Groupings**: Ensure accuracy in categorization, adjusting terms to refine group coherence and relevance.

# Output Format

Provide the output as a list of categories, each followed by their grouped cardiovascular conditions. Clearly label each category and list the terms in an organized manner using bullet points.

# Examples

**Example Start**

- **Heart Diseases**:
  - Myocardial Infarction
  - Coronary Artery Disease

- **Vascular Diseases**:
  - Atherosclerosis
  - Peripheral Artery Disease

- **Congenital Conditions**:
  - Tetralogy of Fallot
  - Ventricular Septal Defect

- **Arrhythmias**:
  - Atrial Fibrillation
  - Ventricular Tachycardia

**Example End**

# Notes

- Ensure terms are verified for correct categorization.
- Explore subcategories if needed for complex conditions to enhance understanding.
- The focus is solely on diseases and conditions. Ensure clarity for medical educational purposes."""
                },
                {
                    "role": "user",
                    "content": prompt
                }
            ],
            max_tokens=16000,  # Adjust if necessary for your use case
            temperature=0.5  # Low temperature for clearer, more focused responses
        )

        # Extract the full response text from the chat model response
        full_response = response.choices[0].message.content

        # Append the response to the all_responses list
        all_responses.append(full_response)

    # Combine all responses into one (optional, depending on your needs)
    final_response = "\n".join(all_responses)
    
    return final_response  # Return the combined response or process it further

# %%
sampled_terms = concepts_syn_df.sample(n=500, replace=False, random_state=42)
full_terms = concepts_syn_df['concept_name'].unique()
# sample_list = sampled_terms['concept_name'].unique()

ancestors_list = ['acute disease of cardiovascular system', 'aneurysm',
       'cardiac arrhythmia', 'cardiovascular injury',
       'chronic disease of cardiovascular system',
       'congenital anomaly of cardiovascular structure of trunk',
       'congenital anomaly of cardiovascular system',
       'congenital vascular disorder', 'embolism', 'heart valve disorder',
       'hemorrhage of blood vessel', 'injury of blood vessel',
       'myocardial disease', 'thrombosis', 'thrombosis of blood vessel',
       'vascular disease of abdomen', 'vascular disorder', 'vasculitis',
       'venous varices']

# %%
result_chunked = generate_term_grouping(full_terms, ancestors_list)
print(result_chunked)
# Out:
# [start chunk 1/5]
# ```json
# {
#   "acute disease of cardiovascular system": [
#     "Acute disease of cardiovascular system",
#     "Acute heart disease",
#     "Acute ischemic heart disease",
#     "Myocardial infarction",
#     "Angina pectoris"
#   ],
#   "cardiac arrhythmia": [
#     "Cardiac arrhythmia",
#     "Supraventricular arrhythmia",
#     "Atrial arrhythmia",
#     "Fibrillation",
#     "Atrial fibrillation"
#   ],
#   "chronic disease of cardiovascular system": [
#     "Chronic disease of cardiovascular system",
#     "Chronic heart disease",
#     "Chronic heart failure",
#     "Ischemic heart disease",
#     "Congestive heart failure",
#     "Heart failure",
#     "Hypertensive heart disease"
#   ],
#   "heart valve disorder": [
#     "Heart valve disorder",
#     "Mitral valve disorder",
#     "Aortic valve disorder",
#     "Non-rheumatic heart valve disorder"
#   ]
# }
# ```
# [end chunk 1/5]
#
# [start chunk 2/5]
# ```json
# {
#   "myocardial disease": [
#     "Myocardial disease",
#     "Cardiomyopathy",
#     "Systolic heart failure",
#     "Diastolic heart failure"
#   ],
#   "thrombosis": [
#     "Thrombosis",
#     "Thrombosis of blood vessel",
#     "Venous thrombosis"
#   ],
#   "vascular disorder": [
#     "Vascular disorder",
#     "Vascular degeneration",
#     "Arteriosclerotic vascular disease",
#     "Atherosclerosis of artery",
#     "Disease of non-coronary systemic artery",
#     "Coronary arteriosclerosis",
#     "Coronary atherosclerosis",
#     "Atherosclerosis of coronary artery without angina pectoris",
#     "Vascular insufficiency"
#   ],
#   "vascular disease of abdomen": [
#     "Vascular disease of abdomen"
#   ]
# }
# ```
# [end chunk 2/5]
#
# [start chunk 3/5]
# ```json
# {
#   "venous varices": [
#     "Venous varices",
#     "Trunk varices",
#     "Pelvic varices",
#     "Hemorrhoids"
#   ],
#   "embolism": [
#     "Embolism"
#   ],
#   "other": [
#     "Benign hypertension",
#     "Benign essential hypertension",
#     "Abnormality of systemic vein",
#     "Cerebrovascular disease",
#     "Vascular headache",
#     "Peripheral vascular disease",
#     "Migraine"
#   ]
# }
# ```
# [end chunk 3/5]
# [start chunk 1/5]
# ```json
# {
#   "acute disease of cardiovascular system": [
#     "Acute myocardial infarction",
#     "Acute heart failure",
#     "Acute systolic heart failure",
#     "Acute diastolic heart failure",
#     "Hypertensive crisis"
#   ],
#   "aneurysm": [
#     "Aneurysm",
#     "Arterial aneurysm",
#     "Aortic aneurysm"
#   ],
#   "cardiac arrhythmia": [
#     "Paroxysmal atrial fibrillation",
#     "Chronic atrial fibrillation",
#     "Tachyarrhythmia",
#     "Atrial flutter",
#     "Heart block",
#     "Sinus node dysfunction"
#   ],
#   "cardiovascular injury": []
# }
# ```
# [end chunk 1/5]
#
# [start chunk 2/5]
# ```json
# {
#   "chronic disease of cardiovascular system": [
#     "Chronic systolic heart failure",
#     "Chronic diastolic heart failure",
#     "Chronic ischemic heart disease",
#     "Hypertensive heart disease without congestive heart failure",
#     "Hypertensive heart failure"
#   ],
#   "congenital anomaly of cardiovascular structure of trunk": [
#     "Congenital anomaly of cardiovascular structure of trunk"
#   ],
#   "congenital anomaly of cardiovascular system": [
#     "Congenital anomaly of cardiovascular system"
#   ],
#   "congenital vascular disorder": []
# }
# ```
# [end chunk 2/5]
#
# [start chunk 3/5]
# ```json
# {
#   "embolism": [
#     "Arterial embolism",
#     "Pulmonary embolism"
#   ],
#   "heart valve disorder": [
#     "Heart valve regurgitation",
#     "Tricuspid valve disorder",
#     "Heart valve stenosis",
#     "Abnormality of aortic valve"
#   ],
#   "hemorrhage of blood vessel": [],
#   "injury of blood vessel": []
# }
# ```
# [end chunk 3/5]
#
# [start chunk 4/5]
# ```json
# {
#   "myocardial disease": [
#     "Primary cardiomyopathy",
#     "Cardiomegaly"
#   ],
#   "thrombosis": [
#     "Deep venous thrombosis",
#     "Thrombosis of vein of lower limb",
#     "Deep venous thrombosis of lower extremity",
#     "Acute deep venous thrombosis",
#     "Acute deep vein thrombosis of lower limb"
#   ],
#   "thrombosis of blood vessel": [],
#   "vascular disease of abdomen": []
# }
# ```
# [end chunk 4/5]
#
# [start chunk 5/5]
# ```json
# {
#   "vascular disorder": [
#     "Obstruction of precerebral artery",
#     "Carotid artery obstruction",
#     "Peripheral vascular disorder due to diabetes mellitus",
#     "Peripheral circulatory disorder due to type 2 diabetes mellitus",
#     "Peripheral venous insufficiency"
#   ],
#   "vasculitis": [
#     "Vasculitis",
#     "Phlebitis"
#   ],
#   "venous varices": [
#     "Varicose veins of lower extremity"
#   ],
#   "other": [
#     "Low blood pressure",
#     "Old myocardial infarction",
#     "Dilatation of aorta",
#     "Transient cerebral ischemia",
#     "Disease of circulatory system complicating pregnancy childbirth and puerperium",
#     "Intraventricular conduction defect",
#     "Bundle branch block",
#     "Migraine without aura"
#   ]
# }
# ```
# [end chunk 5/5]
# [start chunk 1/5]
# ```json
# {
#   "acute disease of cardiovascular system": [
#     "Hypertensive emergency",
#     "Acute on chronic systolic heart failure",
#     "Acute on chronic diastolic heart failure",
#     "Acute subendocardial infarction",
#     "Subendocardial ischemia",
#     "Subendocardial myocardial infarction",
#     "Preinfarction syndrome"
#   ],
#   "aneurysm": [
#     "Aneurysm of descending aorta"
#   ],
#   "cardiac arrhythmia": [
#     "Paroxysmal tachycardia",
#     "Ventricular tachycardia",
#     "Supraventricular tachycardia",
#     "Premature beats",
#     "Atrioventricular conduction disorder",
#     "Atrioventricular block"
#   ],
#   "cardiovascular injury": []
# }
# ```
# [end chunk 1/5]
#
# [start chunk 2/5]
# ```json
# {
#   "chronic disease of cardiovascular system": [
#     "Chronic combined systolic and diastolic heart failure",
#     "Non-rheumatic mitral valve disease",
#     "Benign hypertensive heart disease",
#     "Benign hypertensive heart disease without congestive heart failure",
#     "Hypertensive heart and renal disease with (congestive) heart failure",
#     "Hypertensive heart AND renal disease"
#   ],
#   "congenital anomaly of cardiovascular structure of trunk": [],
#   "congenital anomaly of cardiovascular system": [
#     "Congenital heart disease",
#     "Cardiac septal defects"
#   ],
#   "congenital vascular disorder": [
#     "Congenital vascular disorder",
#     "Congenital vascular malformation"
#   ]
# }
# ```
# [end chunk 2/5]
#
# [start chunk 3/5]
# ```json
# {
#   "embolism": [
#     "Pulmonary embolism with pulmonary infarction",
#     "Embolism from thrombosis of vein of lower extremity"
#   ],
#   "heart valve disorder": [
#     "Mitral valve regurgitation",
#     "Mitral valve stenosis",
#     "Mitral stenosis with insufficiency",
#     "Non-rheumatic mitral valve stenosis",
#     "Non-rheumatic mitral regurgitation",
#     "Non-rheumatic mitral valve stenosis with regurgitation",
#     "Heart valve stenosis and regurgitation",
#     "Tricuspid valve disorder, non-rheumatic"
#   ],
#   "hemorrhage of blood vessel": []
# }
# ```
# [end chunk 3/5]
#
# [start chunk 4/5]
# ```json
# {
#   "injury of blood vessel": [],
#   "myocardial disease": [],
#   "thrombosis": [
#     "Thrombophlebitis"
#   ],
#   "thrombosis of blood vessel": []
# }
# ```
# [end chunk 4/5]
#
# [start chunk 5/5]
# ```json
# {
#   "vascular disease of abdomen": [
#     "Abnormality of abdominal aorta",
#     "Dilatation of descending aorta",
#     "Abdominal aortic ectasia",
#     "Arteriosclerosis of aorta",
#     "Atherosclerosis of aorta"
#   ],
#   "vascular disorder": [
#     "Pulmonary hypertension",
#     "Peripheral arterial occlusive disease",
#     "Occlusion of artery",
#     "Retinal vascular disorder"
#   ],
#   "vasculitis": [
#     "Phlebitis of lower limb vein"
#   ],
#   "venous varices": [],
#   "other": [
#     "Malignant hypertension",
#     "Malignant essential hypertension",
#     "Pregnancy-induced hypertension",
#     "Refractory migraine",
#     "Migraine with aura"
#   ]
# }
# ```
# [end chunk 5/5]
# [start chunk 1/5]
# ```json
# {
#   "acute disease of cardiovascular system": [
#     "Acute non-ST segment elevation myocardial infarction",
#     "Acute combined systolic and diastolic heart failure"
#   ],
#   "aneurysm": [
#     "Aneurysm of thoracic aorta"
#   ],
#   "cardiac arrhythmia": [
#     "Paroxysmal ventricular tachycardia",
#     "Aberrant premature complexes",
#     "Sick sinus syndrome",
#     "Paroxysmal supraventricular tachycardia",
#     "Persistent atrial fibrillation",
#     "Ventricular premature complex"
#   ],
#   "cardiovascular injury": [
#     "Cardiac arrest"
#   ],
#   "chronic disease of cardiovascular system": [
#     "Chronic peripheral venous hypertension",
#     "Pulmonary arterial hypertension",
#     "Secondary pulmonary hypertension"
#   ],
#   "congenital anomaly of cardiovascular structure of trunk": []
# }
# ```
# [end chunk 1/5]
#
# [start chunk 2/5]
# ```json
# {
#   "congenital anomaly of cardiovascular system": [
#     "Atrial septal defect",
#     "Congenital anomaly of heart valve"
#   ],
#   "congenital vascular disorder": [],
#   "embolism": [
#     "Thromboembolic disorder"
#   ],
#   "heart valve disorder": [
#     "Valvular sclerosis",
#     "Non-rheumatic aortic sclerosis",
#     "Aortic valve regurgitation",
#     "Rheumatic heart disease",
#     "Multiple valve disease",
#     "Rheumatic disease of heart valve",
#     "Diseases of mitral and aortic valves",
#     "Pulmonary valve disorder"
#   ],
#   "hemorrhage of blood vessel": [
#     "Hemorrhage of blood vessel"
#   ],
#   "injury of blood vessel": []
# }
# ```
# [end chunk 2/5]
#
# [start chunk 3/5]
# ```json
# {
#   "myocardial disease": [
#     "Myocardial dysfunction",
#     "Ischemic myocardial dysfunction",
#     "Generalized ischemic myocardial dysfunction"
#   ],
#   "thrombosis": [
#     "Arterial thrombosis"
#   ],
#   "thrombosis of blood vessel": [
#     "Thrombophlebitis of lower extremities"
#   ],
#   "vascular disease of abdomen": []
# }
# ```
# [end chunk 3/5]
#
# [start chunk 4/5]
# ```json
# {
#   "vascular disorder": [
#     "Orthostatic hypotension",
#     "Venous hypertension",
#     "Arterial malformation",
#     "Ectasia of thoracic aorta",
#     "Cerebral arteriosclerosis",
#     "Cerebral atherosclerosis",
#     "Systemic vein obstruction",
#     "Precerebral arterial occlusion"
#   ],
#   "vasculitis": [
#     "Carditis",
#     "Endocarditis",
#     "Endocardial disease"
#   ],
#   "venous varices": [
#     "Varicose veins of lower extremity with inflammation"
#   ]
# }
# ```
# [end chunk 4/5]
#
# [start chunk 5/5]
# ```json
# {
#   "other": [
#     "Left bundle branch block",
#     "Right bundle branch block",
#     "Partial atrioventricular block",
#     "Complete atrioventricular block",
#     "Retinal vascular occlusion",
#     "Hypertension in the obstetric context",
#     "Pre-existing hypertension in obstetric context",
#     "Refractory migraine without aura"
#   ]
# }
# ```
# [end chunk 5/5]
# [start chunk 1/5]
# ```json
# {
#     "acute disease of cardiovascular system": [
#         "Acute ST segment elevation myocardial infarction",
#         "Acute on chronic combined systolic and diastolic heart failure",
#         "Pre-eclampsia"
#     ],
#     "aneurysm": [],
#     "cardiac arrhythmia": [
#         "First degree atrioventricular block"
#     ],
#     "cardiovascular injury": [],
#     "chronic disease of cardiovascular system": [
#         "Hypertensive heart and chronic kidney disease",
#         "Chronic peripheral venous hypertension with lower extremity complication",
#         "Non-proteinuric hypertension of pregnancy"
#     ],
#     "congenital anomaly of cardiovascular structure of trunk": []
# }
# ```
# [end chunk 1/5]
#
# [start chunk 2/5]
# ```json
# {
#     "congenital anomaly of cardiovascular system": [
#         "Ventricular septal defect",
#         "Ostium secundum type atrial septal defect",
#         "Congenital anomaly of aorta",
#         "Congenital abnormality of systemic artery"
#     ],
#     "congenital vascular disorder": [],
#     "embolism": [
#         "Arterial embolus and thrombosis"
#     ],
#     "heart valve disorder": [
#         "Tricuspid valve regurgitation",
#         "Aortic incompetence, non-rheumatic",
#         "Tricuspid incompetence, non-rheumatic",
#         "Aortic valve stenosis",
#         "Abnormality of pulmonary valve"
#     ],
#     "hemorrhage of blood vessel": [
#         "Gastric hemorrhage"
#     ]
# }
# ```
# [end chunk 2/5]
#
# [start chunk 3/5]
# ```json
# {
#     "injury of blood vessel": [],
#     "myocardial disease": [
#         "Ischemia",
#         "Left ventricular abnormality",
#         "Dilated cardiomyopathy",
#         "Cardiomyopathy associated with another disorder"
#     ],
#     "thrombosis": [],
#     "thrombosis of blood vessel": [
#         "Thrombosis of retinal vein",
#         "Thrombosis of vein of upper limb",
#         "Thrombosis of vein of trunk",
#         "Thrombosis of arteries of the extremities"
#     ],
#     "vascular disease of abdomen": [
#         "Vascular insufficiency of intestine",
#         "Portal hypertension",
#         "Esophageal varices"
#     ]
# }
# ```
# [end chunk 3/5]
#
# [start chunk 4/5]
# ```json
# {
#     "vascular disorder": [
#         "Secondary hypertension",
#         "Cerebral ischemia",
#         "Renal vascular disorder",
#         "Stenosis of artery",
#         "Raynaud's disease",
#         "Nephrosclerosis",
#         "Generalized atherosclerosis",
#         "Peripheral vascular complication",
#         "Vascular disease of the skin"
#     ],
#     "vasculitis": [
#         "Systemic vasculitis",
#         "Arteritis"
#     ],
#     "venous varices": [],
#     "other": [
#         "Phlebitis of deep veins of lower extremity",
#         "Deep thrombophlebitis",
#         "Thrombophlebitis of deep veins of lower extremity",
#         "Heritable pulmonary arterial hypertension",
#         "Status migrainosus",
#         "Valvular endocarditis",
#         "Multiple and bilateral precerebral arterial occlusion",
#         "Left heart failure",
#         "Transformed migraine",
#         "Chronic intractable migraine without aura"
#     ]
# }
# ```
# [end chunk 4/5]
#
# [start chunk 5/5]
# ```json
# {
#     "aneurysm": []
# }
# ```
# [end chunk 5/5]
# [start chunk 1/5]
# ```json
# {
#   "acute disease of cardiovascular system": [
#     "Acute myocardial infarction of inferior wall",
#     "Cardiogenic shock",
#     "Hypertensive urgency"
#   ],
#   "aneurysm": [
#     "Aneurysm of artery, other than aorta"
#   ],
#   "cardiac arrhythmia": [
#     "Ectopic beats",
#     "Supraventricular premature beats",
#     "Second degree atrioventricular block",
#     "Ventricular arrhythmia",
#     "Ventricular fibrillation"
#   ],
#   "cardiovascular injury": [
#     "Dissection of artery"
#   ]
# }
# ```
# [end chunk 1/5]
#
# [start chunk 2/5]
# ```json
# {
#   "chronic disease of cardiovascular system": [
#     "Hypertensive heart disease with congestive heart failure",
#     "Hypertensive heart AND chronic kidney disease stage 5",
#     "Benign essential hypertension complicating pregnancy, childbirth and the puerperium - not delivered"
#   ],
#   "congenital anomaly of cardiovascular structure of trunk": [
#     "Congenital anomaly of aortic valve",
#     "Congenital stenosis of pulmonary valve",
#     "Congenital abnormality of cardiac connection"
#   ],
#   "congenital anomaly of cardiovascular system": [
#     "Patent ductus arteriosus",
#     "Congenital stenosis of cardiac valve",
#     "Congenital septal defect of heart",
#     "Congenital insufficiency of aortic valve",
#     "Congenital pulmonary valve abnormality"
#   ],
#   "congenital vascular disorder": [
#     "Congenital valvular insufficiency"
#   ]
# }
# ```
# [end chunk 2/5]
#
# [start chunk 3/5]
# ```json
# {
#   "embolism": [
#     "Venous embolism"
#   ],
#   "heart valve disorder": [
#     "Rheumatic disease of mitral valve",
#     "Mitral and aortic incompetence",
#     "Cardiac valve prolapse",
#     "Mitral valve prolapse",
#     "Rheumatic heart valve regurgitation",
#     "Pulmonic valve stenosis"
#   ],
#   "hemorrhage of blood vessel": [
#     "Arterial hemorrhage"
#   ],
#   "injury of blood vessel": [
#     "Compression of vein"
#   ]
# }
# ```
# [end chunk 3/5]
#
# [start chunk 4/5]
# ```json
# {
#   "myocardial disease": [
#     "Hypertrophic cardiomyopathy",
#     "Right ventricular abnormality"
#   ],
#   "thrombosis": [
#     "Thrombosis of arteries of lower extremity",
#     "Thrombosis of pelvic vein"
#   ],
#   "thrombosis of blood vessel": [
#     "Deep venous thrombosis of upper extremity",
#     "Acute deep venous thrombosis of upper extremity",
#     "Superficial vein thrombosis"
#   ],
#   "vascular disease of abdomen": [
#     "Atherosclerosis of renal artery"
#   ]
# }
# ```
# [end chunk 4/5]
#
# [start chunk 5/5]
# ```json
# {
#   "vascular disorder": [
#     "Stricture of artery",
#     "Coronary occlusion"
#   ],
#   "vasculitis": [
#     "Small vessel vasculitis"
#   ],
#   "venous varices": [
#     "Esophageal varices without bleeding"
#   ],
#   "other": [
#     "Pericardial effusion",
#     "Pericardial effusion - noninflammatory",
#     "Central retinal vein occlusion",
#     "Venous retinal branch occlusion",
#     "Transient hypertension of pregnancy",
#     "Infective endocarditis",
#     "Cardiovascular system complication of procedure"
#   ]
# }
# ```
# [end chunk 5/5]
# [start chunk 1/5]
# ```json
# {
#   "acute disease of cardiovascular system": [
#     "Acute myocardial infarction of anterior wall",
#     "Acute endocarditis",
#     "Acute vascular insufficiency of intestine"
#   ],
#   "aneurysm": [
#     "Dissection of aorta"
#   ],
#   "cardiac arrhythmia": [
#     "Atrial premature complex",
#     "Long QT syndrome"
#   ],
#   "cardiovascular injury": [
#     "Cardiovascular injury"
#   ],
#   "chronic disease of cardiovascular system": [
#     "Chronic total occlusion of coronary artery",
#     "Chronic deep venous thrombosis",
#     "Chronic deep venous thrombosis of lower extremity",
#     "Chronic venous thrombosis"
#   ]
# }
# ```
# [end chunk 1/5]
#
# [start chunk 2/5]
# ```json
# {
#   "congenital anomaly of cardiovascular structure of trunk": [
#     "Congenital anomaly of coronary artery",
#     "Congenital hypertrophy of cardiac ventricle"
#   ],
#   "congenital anomaly of cardiovascular system": [
#     "Congenital arteriovenous malformation"
#   ],
#   "congenital vascular disorder": [
#     "Congenital arteriovenous malformation"
#   ],
#   "embolism": [
#     "Thromboembolism of vein"
#   ],
#   "heart valve disorder": [
#     "Disorders of both mitral and tricuspid valves",
#     "Rheumatic disease of tricuspid valve",
#     "Rheumatic disease of aortic valve",
#     "Rheumatic tricuspid valve regurgitation"
#   ]
# }
# ```
# [end chunk 2/5]
#
# [start chunk 3/5]
# ```json
# {
#   "hemorrhage of blood vessel": [
#     "Esophageal varices associated with another disorder",
#     "Gastric ulcer with hemorrhage"
#   ],
#   "injury of blood vessel": [
#     "Coronary artery spasm"
#   ],
#   "myocardial disease": [
#     "Right ventricular failure",
#     "Right ventricular hypertrophy",
#     "Ventricular hypertrophy",
#     "Cor pulmonale"
#   ],
#   "thrombosis": [
#     "Deep venous thrombosis of profunda femoris vein",
#     "Thromboembolism of vein"
#   ]
# }
# ```
# [end chunk 3/5]
#
# [start chunk 4/5]
# ```json
# {
#   "thrombosis of blood vessel": [
#     "Superficial thrombophlebitis",
#     "Phlebitis of deep femoral vein"
#   ],
#   "vascular disease of abdomen": [
#     "Angiodysplasia of intestine"
#   ],
#   "vascular disorder": [
#     "Peripheral circulatory disorder due to type 1 diabetes mellitus",
#     "Arterial insufficiency",
#     "Arteriosclerosis of artery of extremity"
#   ],
#   "vasculitis": [
#     "Antineutrophil cytoplasmic antibody positive vasculitis",
#     "Granulomatosis with polyangiitis"
#   ],
#   "venous varices": [
#     "Varicose veins of lower extremity with ulcer AND inflammation"
#   ]
# }
# ```
# [end chunk 4/5]
#
# [start chunk 5/5]
# ```json
# {
#   "other": [
#     "Flushing",
#     "Refractory migraine with aura",
#     "Migraine variants",
#     "Pre-existing hypertension complicating pregnancy, childbirth and puerperium",
#     "Cerebrovascular accident",
#     "Retinal neovascularization",
#     "Hypertension complicating pregnancy, childbirth and the puerperium",
#     "Severe pre-eclampsia",
#     "Malignant hypertensive heart disease",
#     "Malignant hypertensive heart disease without congestive heart failure",
#     "Benign hypertensive heart disease with congestive cardiac failure",
#     "Hypertensive heart AND chronic kidney disease with congestive heart failure",
#     "Renal hypertension"
#   ]
# }
# ```
# [end chunk 5/5]
# [start chunk 1/5]
# ```json
# {
#   "acute disease of cardiovascular system": [
#     "Acute pericarditis",
#     "Acute cerebrovascular insufficiency",
#     "Acute cor pulmonale",
#     "Acute myocardial infarction of anterolateral wall",
#     "Acute infective endocarditis",
#     "Acute bacterial endocarditis"
#   ],
#   "aneurysm": [
#     "Aneurysm of artery of lower extremity",
#     "Aneurysm of iliac artery"
#   ],
#   "cardiac arrhythmia": [
#     "Typical atrial flutter",
#     "Bradyarrhythmia",
#     "Bifascicular block",
#     "Neonatal bradycardia"
#   ],
#   "cardiovascular injury": [
#     "Injury of blood vessel"
#   ]
# }
# ```
# [end chunk 1/5]
#
# [start chunk 2/5]
# ```json
# {
#   "chronic disease of cardiovascular system": [
#     "Chronic pulmonary embolism",
#     "Chronic vascular insufficiency of intestine"
#   ],
#   "congenital anomaly of cardiovascular structure of trunk": [
#     "Coarctation of aorta"
#   ],
#   "congenital anomaly of cardiovascular system": [
#     "Congenital hypoplasia of heart",
#     "Hypoplastic left heart syndrome",
#     "Congenital anomaly of mitral valve",
#     "Congenital anomaly of pulmonary artery"
#   ],
#   "congenital vascular disorder": [
#     "Congenital anomaly of cerebrovascular system",
#     "Congenital anomaly of peripheral blood vessel"
#   ]
# }
# ```
# [end chunk 2/5]
#
# [start chunk 3/5]
# ```json
# {
#   "embolism": [
#     "Chronic pulmonary embolism"
#   ],
#   "heart valve disorder": [
#     "Rheumatic heart valve stenosis",
#     "Rheumatic disease of mitral AND aortic valves",
#     "Disorders of both aortic and tricuspid valves",
#     "Pulmonic valve regurgitation"
#   ],
#   "hemorrhage of blood vessel": [
#     "Chronic gastric ulcer with hemorrhage",
#     "Gastric ulcer with hemorrhage but without obstruction"
#   ],
#   "injury of blood vessel": [
#     "Injury of blood vessel"
#   ]
# }
# ```
# [end chunk 3/5]
#
# [start chunk 4/5]
# ```json
# {
#   "myocardial disease": [
#     "Hypertrophic obstructive cardiomyopathy"
#   ],
#   "thrombosis": [
#     "Thrombosis of the popliteal vein",
#     "Acute thrombosis of superficial vein of upper extremity"
#   ],
#   "thrombosis of blood vessel": [
#     "Portal vein thrombosis"
#   ],
#   "vascular disease of abdomen": [
#     "Chronic vascular insufficiency of intestine"
#   ]
# }
# ```
# [end chunk 4/5]
#
# [start chunk 5/5]
# ```json
# {
#   "vascular disorder": [
#     "Renovascular hypertension",
#     "Maternal hypertension",
#     "Transient hypertension of pregnancy - delivered"
#   ],
#   "vasculitis": [
#     "Hypersensitivity angiitis"
#   ],
#   "venous varices": [
#     "Thrombophlebitis of superficial veins of lower extremity",
#     "Thrombophlebitis of upper extremities"
#   ],
#   "other": [
#     "Neonatal cardiovascular disorder",
#     "Cardiac complication",
#     "Low blood pressure reading",
#     "Neonatal dysrhythmia",
#     "Bacterial infectious disease of heart",
#     "Bacterial endocarditis",
#     "Subacute endocarditis",
#     "Acute and subacute endocarditis",
#     "Subacute bacterial endocarditis",
#     "Atherosclerosis of arteries of the extremities",
#     "Dissection of thoracic aorta",
#     "Peripheral angiopathy due to diabetes mellitus"
#   ]
# }
# ```
# [end chunk 5/5]
# [start chunk 1/5]
# ```json
# {
#   "acute disease of cardiovascular system": [
#     "Acute gastric ulcer with hemorrhage",
#     "Acute hemorrhagic gastritis",
#     "Pre-eclampsia or eclampsia with pre-existing hypertension",
#     "CLABSI - central line associated bloodstream infection"
#   ],
#   "aneurysm": [
#     "Aneurysm of heart"
#   ],
#   "cardiac arrhythmia": [
#     "Atypical atrial flutter",
#     "Anomalous atrioventricular excitation"
#   ],
#   "cardiovascular injury": [
#     "Injury of artery"
#   ]
# }
# ```
# [end chunk 1/5]
#
# [start chunk 2/5]
# ```json
# {
#   "chronic disease of cardiovascular system": [
#     "Chronic right-sided heart failure",
#     "Chronic gastric ulcer with hemorrhage but without obstruction"
#   ],
#   "congenital anomaly of cardiovascular structure of trunk": [
#     "Congenital insufficiency of mitral valve",
#     "Congenital anomaly of tricuspid valve"
#   ],
#   "congenital anomaly of cardiovascular system": [
#     "Discordant ventriculoarterial connection"
#   ],
#   "congenital vascular disorder": [
#     "Vascular anomaly of umbilical cord",
#     "Velamentous insertion of umbilical cord"
#   ]
# }
# ```
# [end chunk 2/5]
#
# [start chunk 3/5]
# ```json
# {
#   "embolism": [
#     "Septic embolus of artery"
#   ],
#   "heart valve disorder": [
#     "Mitral insufficiency and aortic stenosis",
#     "Combined disorders of mitral, aortic and tricuspid valves",
#     "Rheumatic mitral regurgitation",
#     "Aortic valve stenosis with insufficiency",
#     "Pulmonary incompetence, non-rheumatic"
#   ],
#   "hemorrhage of blood vessel": [
#     "Venous hemorrhage",
#     "Rupture of artery"
#   ],
#   "injury of blood vessel": [
#     "Dissection of cervicocerebral artery",
#     "Dissection of precerebral artery"
#   ]
# }
# ```
# [end chunk 3/5]
#
# [start chunk 4/5]
# ```json
# {
#   "myocardial disease": [
#     "Myocarditis",
#     "Takotsubo cardiomyopathy"
#   ],
#   "thrombosis": [
#     "Thrombosis of superficial vein of lower limb"
#   ],
#   "thrombosis of blood vessel": [
#     "Branch retinal vein occlusion with macular edema"
#   ],
#   "vascular disease of abdomen": [
#     "Angiodysplasia of small intestine",
#     "Angiodysplasia of duodenum",
#     "Angiodysplasia of stomach"
#   ]
# }
# ```
# [end chunk 4/5]
#
# [start chunk 5/5]
# ```json
# {
#   "vascular disorder": [
#     "Autoimmune vasculitis",
#     "Vascular insufficiency of limb",
#     "Atherosclerosis of bypass graft of limb",
#     "Arteriovenous fistula",
#     "Vascular complication of medical care",
#     "Penile arterial insufficiency",
#     "Arteriosclerotic gangrene"
#   ],
#   "vasculitis": [
#     "Henoch-Schönlein purpura"
#   ],
#   "venous varices": [
#     "Varicose veins of lower extremity without ulcer AND without inflammation"
#   ],
#   "other": [
#     "Venous complication of pregnancy and/or the puerperium",
#     "Venous insufficiency of leg",
#     "Secondary venous insufficiency of leg",
#     "Postthrombotic syndrome",
#     "Heart disease in mother complicating pregnancy, childbirth AND/OR puerperium",
#     "Mallory-Weiss syndrome",
#     "Phlebitis of superficial veins of lower extremity",
#     "Menstrual migraine"
#   ]
# }
# ```
# [end chunk 5/5]
# [start chunk 1/5]
# ```json
# {
#   "acute disease of cardiovascular system": [
#     "Carotid territory transient ischemic attack",
#     "Vertebrobasilar territory transient ischemic attack",
#     "Basilar artery syndrome",
#     "Rupture of aorta",
#     "Acute deep venous thrombosis of internal jugular vein",
#     "Severe pre-eclampsia - delivered",
#     "Bleeding esophageal varices"
#   ],
#   "aneurysm": [
#     "Aneurysm of head and neck artery",
#     "Ruptured aneurysm of artery",
#     "Aneurysm of visceral artery"
#   ],
#   "cardiac arrhythmia": [
#     "Accelerated atrioventricular conduction"
#   ],
#   "cardiovascular injury": [
#     "Injury of systemic artery"
#   ]
# }
# ```
# [end chunk 1/5]
#
# [start chunk 2/5]
# ```json
# {
#   "chronic disease of cardiovascular system": [
#     "Chronic cor pulmonale",
#     "Hypertensive heart and renal disease with both (congestive) heart failure and renal failure",
#     "Nonischemic congestive cardiomyopathy",
#     "Secondary dilated cardiomyopathy",
#     "Secondary nonischemic congestive cardiomyopathy",
#     "Restrictive cardiomyopathy",
#     "Benign essential hypertension complicating pregnancy, childbirth and the puerperium - delivered"
#   ],
#   "congenital anomaly of cardiovascular structure of trunk": [
#     "Congenital atresia of aorta"
#   ],
#   "congenital anomaly of cardiovascular system": [
#     "Endocardial cushion defect",
#     "Congenital stenosis of aortic valve"
#   ],
#   "congenital vascular disorder": [
#     "Congenital abnormality of vein"
#   ]
# }
# ```
# [end chunk 2/5]
#
# [start chunk 3/5]
# ```json
# {
#   "embolism": [
#     "Saddle embolus of pulmonary artery",
#     "Septic pulmonary embolism"
#   ],
#   "heart valve disorder": [
#     "Tricuspid valve stenosis",
#     "Rheumatic mitral stenosis",
#     "Rheumatic aortic stenosis",
#     "Mitral and aortic stenosis"
#   ],
#   "hemorrhage of blood vessel": [],
#   "injury of blood vessel": [],
#   "myocardial disease": []
# }
# ```
# [end chunk 3/5]
#
# [start chunk 4/5]
# ```json
# {
#   "thrombosis": [
#     "Thrombotic microangiopathy",
#     "Thrombus of cardiac chamber"
#   ],
#   "thrombosis of blood vessel": [
#     "Thrombosis of iliac artery"
#   ],
#   "vascular disease of abdomen": [
#     "Dissection of abdominal aorta"
#   ],
#   "vascular disorder": [
#     "Aortic thromboembolism",
#     "Carotid artery stenosis",
#     "Carotid artery occlusion",
#     "Stenosis of precerebral artery",
#     "Vertebral artery obstruction",
#     "Retinal artery occlusion",
#     "Central retinal vein occlusion with macular edema",
#     "Transient arterial retinal occlusion"
#   ]
# }
# ```
# [end chunk 4/5]
#
# [start chunk 5/5]
# ```json
# {
#   "vasculitis": [
#     "Behcet's syndrome",
#     "Acute febrile mucocutaneous lymph node syndrome"
#   ],
#   "venous varices": [],
#   "other": [
#     "Cardiovascular system hereditary disorder",
#     "Perinatal cardiovascular disorders",
#     "Drug-induced hypotension",
#     "Hemodialysis-associated hypotension",
#     "Vascular hamartomas",
#     "Venous malformation",
#     "Cerebral arteriovenous malformation"
#   ]
# }
# ```
# [end chunk 5/5]
# [start chunk 1/5]
# ```json
# {
#   "acute disease of cardiovascular system": [
#     "Acute ST segment elevation myocardial infarction involving left anterior descending coronary artery",
#     "Acute coronary artery occlusion not resulting in myocardial infarction",
#     "Acute myocardial infarction due to right coronary artery occlusion",
#     "Acute ST segment elevation myocardial infarction due to right coronary artery occlusion",
#     "Acute myocardial infarction of inferolateral wall"
#   ],
#   "aneurysm": [],
#   "cardiac arrhythmia": [],
#   "cardiovascular injury": [],
#   "chronic disease of cardiovascular system": [
#     "Chronic hypotension",
#     "Malignant hypertensive heart disease with congestive heart failure",
#     "Hypertensive heart and renal disease with renal failure",
#     "Benign secondary hypertension"
#   ],
#   "congenital anomaly of cardiovascular structure of trunk": [
#     "Abnormality of aortic arch",
#     "Congenital stenosis of aorta",
#     "Ascending aorta abnormality"
#   ]
# }
# ```
# [end chunk 1/5]
#
# [start chunk 2/5]
# ```json
# {
#   "congenital anomaly of cardiovascular system": [
#     "Atrioventricular septal defect and common atrioventricular junction",
#     "Congenital atresia of pulmonary valve"
#   ],
#   "congenital vascular disorder": [
#     "Osler hemorrhagic telangiectasia syndrome"
#   ],
#   "embolism": [
#     "Embolism of vena cava",
#     "Embolism and thrombosis of the vena cava",
#     "Embolism of iliac artery"
#   ],
#   "heart valve disorder": [
#     "Abnormality of atrioventricular (non-mitral, non-tricuspid) valve",
#     "Aortic valve cusp abnormality"
#   ],
#   "hemorrhage of blood vessel": [
#     "Acute gastric ulcer with hemorrhage but without obstruction"
#   ]
# }
# ```
# [end chunk 2/5]
#
# [start chunk 3/5]
# ```json
# {
#   "injury of blood vessel": [],
#   "myocardial disease": [
#     "Dilated cardiomyopathy secondary to alcohol"
#   ],
#   "thrombosis": [
#     "Thrombosis of subclavian vein",
#     "Thrombosis of vena cava",
#     "Acute thrombosis of subclavian vein",
#     "Thrombosis of arteries of upper extremity",
#     "Cerebral thrombosis",
#     "Thrombotic stroke"
#   ],
#   "thrombosis of blood vessel": [
#     "Thrombosis of abdominal aorta",
#     "Embolism and thrombosis of the abdominal aorta",
#     "Thrombophlebitis of superficial veins of upper extremities",
#     "Deep venous thrombosis of tibial vein",
#     "Acute deep venous thrombosis of axillary vein",
#     "Axillary vein thrombosis"
#   ],
#   "vascular disease of abdomen": [],
#   "vascular disorder": [
#     "Telangiectasia disorder",
#     "Cutaneous vascular malformation",
#     "Angiodysplasia of colon",
#     "Male genital organ vascular diseases"
#   ]
# }
# ```
# [end chunk 3/5]
#
# [start chunk 4/5]
# ```json
# {
#   "vasculitis": [],
#   "venous varices": [],
#   "other": [
#     "Central retinal artery occlusion",
#     "Arterial retinal branch occlusion",
#     "Prinzmetal angina",
#     "Angina decubitus",
#     "Cardiac tamponade",
#     "Mural thrombus of heart",
#     "Refractory migraine variants",
#     "Cerebellar stroke syndrome",
#     "Moyamoya disease",
#     "Atresia of pulmonary valve",
#     "Post cardiac operation functional disturbance",
#     "Mild pre-eclampsia"
#   ]
# }
# ```
# [end chunk 4/5]
# [start chunk 1/5]
# ```json
# {
#   "acute disease of cardiovascular system": [
#     "Acute idiopathic pericarditis",
#     "Subclavian steal syndrome",
#     "Subaortic stenosis"
#   ],
#   "aneurysm": [
#     "Aneurysm of renal artery"
#   ],
#   "cardiac arrhythmia": [
#     "Atrial fibrillation and flutter",
#     "Ventricular premature beats"
#   ],
#   "cardiovascular injury": [
#     "Mechanical complication of arteriovenous surgical fistula"
#   ],
#   "chronic disease of cardiovascular system": [
#     "Chronic passive congestion of liver",
#     "Chronic occlusion of artery of extremity",
#     "Chronic deep venous thrombosis of upper extremity"
#   ]
# }
# ```
# [end chunk 1/5]
#
# [start chunk 2/5]
# ```json
# {
#   "congenital anomaly of cardiovascular structure of trunk": [
#     "Congenital anomaly of aortic arch"
#   ],
#   "congenital anomaly of cardiovascular system": [
#     "Congenital anomaly of pulmonary veins",
#     "Congenital stenosis of tricuspid valve",
#     "Congenital malposition of heart"
#   ],
#   "congenital vascular disorder": [
#     "Anomalies of great veins"
#   ],
#   "embolism": [
#     "Cerebral embolism",
#     "Embolism from thrombosis of vein of distal lower extremity"
#   ],
#   "heart valve disorder": [
#     "Aortic cusp regurgitation",
#     "Rheumatic aortic regurgitation",
#     "Tricuspid stenosis, non-rheumatic",
#     "Tricuspid leaflet abnormality"
#   ]
# }
# ```
# [end chunk 2/5]
#
# [start chunk 3/5]
# ```json
# {
#   "hemorrhage of blood vessel": [
#     "Amaurosis fugax"
#   ],
#   "injury of blood vessel": [
#     "Injury of blood vessels of upper extremity",
#     "Injury to blood vessels of lower limb"
#   ],
#   "myocardial disease": [
#     "Subsequent myocardial infarction"
#   ],
#   "thrombosis": [
#     "Thrombophlebitis of deep veins of upper extremities",
#     "Thromboangiitis",
#     "Thromboangiitis obliterans"
#   ],
#   "thrombosis of blood vessel": [
#     "Antepartum deep vein thrombosis"
#   ]
# }
# ```
# [end chunk 3/5]
#
# [start chunk 4/5]
# ```json
# {
#   "vascular disease of abdomen": [
#     "Celiac artery compression syndrome",
#     "Budd-Chiari syndrome"
#   ],
#   "vascular disorder": [
#     "Polyarteritis",
#     "Polyarteritis nodosa",
#     "Cerebral vasculitis",
#     "Arterial steal syndrome",
#     "Carotid artery syndrome hemispheric",
#     "Vertebrobasilar artery syndrome"
#   ],
#   "vasculitis": [
#     "Cerebral vasculitis"
#   ],
#   "venous varices": []
# }
# ```
# [end chunk 4/5]
#
# [start chunk 5/5]
# ```json
# {
#   "other": [
#     "Perinatal cyanotic attacks",
#     "Neoplasm of heart",
#     "Hypertension secondary to endocrine disorder",
#     "Phlebitis of the femoral vein",
#     "Acquired arteriovenous fistula",
#     "Pulmonary artery stenosis",
#     "Endocarditis associated with another disorder",
#     "Idiopathic hypotension",
#     "Congestive rheumatic heart failure",
#     "Hemangioma of intracranial structure",
#     "Benign essential hypertension complicating pregnancy, childbirth and the puerperium",
#     "Hemiplegic migraine"
#   ]
# }
# ```
# [end chunk 5/5]
# [start chunk 1/5]
# ```json
# {
#   "acute disease of cardiovascular system": [
#     "Acute myocardial infarction of inferoposterior wall",
#     "Acute myocardial infarction of lateral wall",
#     "Cardiac arrest due to cardiac disorder",
#     "Acute myocarditis"
#   ],
#   "aneurysm": [
#     "Aneurysm of coronary vessels"
#   ],
#   "cardiac arrhythmia": [
#     "Neonatal tachycardia",
#     "Sinus bradycardia",
#     "Ventricular flutter"
#   ],
#   "cardiovascular injury": [
#     "Injury of heart"
#   ]
# }
# ```
# [end chunk 1/5]
#
# [start chunk 2/5]
# ```json
# {
#   "chronic disease of cardiovascular system": [
#     "Postoperative hypertension",
#     "Myocardial degeneration",
#     "Rheumatic heart valve stenosis with insufficiency",
#     "Benign secondary renovascular hypertension",
#     "Severe pre-eclampsia - not delivered",
#     "Pre-eclampsia or eclampsia with pre-existing hypertension - delivered",
#     "Endomyocardial fibrosis",
#     "Takayasu's disease",
#     "Malignant secondary hypertension"
#   ],
#   "congenital anomaly of cardiovascular structure of trunk": [
#     "Common ventricle"
#   ],
#   "congenital anomaly of cardiovascular system": [
#     "Pulmonary stenosis, non-rheumatic",
#     "Congenital atresia of tricuspid valve",
#     "Total anomalous pulmonary venous return",
#     "Anomalous pulmonary venous drainage"
#   ],
#   "congenital vascular disorder": [
#     "Congenital arteriovenous malformation of gastrointestinal tract"
#   ]
# }
# ```
# [end chunk 2/5]
#
# [start chunk 3/5]
# ```json
# {
#   "embolism": [
#     "Cholesterol embolus syndrome",
#     "Embolism of renal vein",
#     "Embolism and thrombosis of the renal vein"
#   ],
#   "heart valve disorder": [
#     "Rheumatic heart valve stenosis with insufficiency"
#   ],
#   "hemorrhage of blood vessel": [],
#   "injury of blood vessel": [
#     "Injury of blood vessels of head AND/OR neck",
#     "Injury of artery of lower limb",
#     "Injury of blood vessels of abdomen AND/OR pelvis",
#     "Injury of systemic artery of trunk"
#   ]
# }
# ```
# [end chunk 3/5]
#
# [start chunk 4/5]
# ```json
# {
#   "myocardial disease": [
#     "Myocardial degeneration",
#     "Acute myocarditis"
#   ],
#   "thrombosis": [
#     "Coronary artery thrombosis",
#     "Coronary thrombosis not resulting in myocardial infarction",
#     "Thrombosis of renal vein"
#   ],
#   "thrombosis of blood vessel": [
#     "Basilar artery occlusion",
#     "Occlusion and stenosis of middle cerebral artery",
#     "Partial retinal artery occlusion"
#   ],
#   "vascular disease of abdomen": [
#     "Gastric varices"
#   ]
# }
# ```
# [end chunk 4/5]
#
# [start chunk 5/5]
# ```json
# {
#   "vascular disorder": [
#     "Retinal telangiectasia",
#     "Microaneurysm of retinal artery",
#     "Vertebral artery syndrome",
#     "Cerebral vasoconstriction syndrome"
#   ],
#   "vasculitis": [
#     "Vasculitis of the skin",
#     "Aortitis"
#   ],
#   "venous varices": [
#     "Gastric varices"
#   ],
#   "other": [
#     "Benign neoplasm of heart",
#     "Migraine with persistent visual aura",
#     "Rubella arthritis",
#     "Hemangioma of skin",
#     "Dissection of coronary artery"
#   ]
# }
# ```
# [end chunk 5/5]
# [start chunk 1/5]
# ```json
# {
#   "acute disease of cardiovascular system": [
#     "Acute bowel infarction",
#     "Acute rheumatic heart disease",
#     "Subsequent non-ST segment elevation myocardial infarction",
#     "Saddle embolus of pulmonary artery with acute cor pulmonale"
#   ],
#   "aneurysm": [
#     "Aneurysm of splenic artery",
#     "Aneurysm of artery of upper extremity",
#     "Carotid artery aneurysm",
#     "Aneurysm of artery of neck"
#   ],
#   "cardiac arrhythmia": [],
#   "cardiovascular injury": [
#     "Contusion to heart",
#     "Rupture of heart",
#     "Cardiac complication of procedure"
#   ]
# }
# ```
# [end chunk 1/5]
#
# [start chunk 2/5]
# ```json
# {
#   "chronic disease of cardiovascular system": [
#     "Chronic pericarditis",
#     "Left ventricular hypertrophy"
#   ],
#   "congenital anomaly of cardiovascular structure of trunk": [],
#   "congenital anomaly of cardiovascular system": [
#     "Congenital conduction defect",
#     "Congenital heart block",
#     "Congenital stenosis of mitral valve",
#     "Partial anomalous pulmonary venous connection"
#   ],
#   "congenital vascular disorder": [
#     "Dieulafoy's vascular malformation",
#     "Angiokeratoma of skin"
#   ]
# }
# ```
# [end chunk 2/5]
#
# [start chunk 3/5]
# ```json
# {
#   "embolism": [
#     "Lower limb arterial embolus",
#     "Carotid artery embolism",
#     "Obstetric pulmonary embolism"
#   ],
#   "heart valve disorder": [
#     "Mitral stenosis and aortic insufficiency",
#     "Mechanical complication due to heart valve prosthesis"
#   ],
#   "hemorrhage of blood vessel": [
#     "Gastric hemorrhage due to atrophic gastritis"
#   ],
#   "injury of blood vessel": [
#     "Injury of vein"
#   ]
# }
# ```
# [end chunk 3/5]
#
# [start chunk 4/5]
# ```json
# {
#   "myocardial disease": [
#     "Postpartum cardiomyopathy"
#   ],
#   "thrombosis": [
#     "Thrombosis of thoracic aorta",
#     "Pulmonary thrombosis"
#   ],
#   "thrombosis of blood vessel": [
#     "Embolism and thrombosis of the thoracic aorta",
#     "Carotid artery thrombosis"
#   ],
#   "vascular disease of abdomen": [],
#   "vascular disorder": [
#     "Carotid atherosclerosis",
#     "Dilatation of pulmonary artery",
#     "Brainstem stroke syndrome"
#   ]
# }
# ```
# [end chunk 4/5]
#
# [start chunk 5/5]
# ```json
# {
#   "vasculitis": [
#     "Retinal vasculitis",
#     "Necrotizing vasculitis",
#     "Cerebral arteritis",
#     "Capillaritis"
#   ],
#   "venous varices": [],
#   "other": [
#     "Peripheral arteriovenous malformation",
#     "Abnormal fetal heart beat first noted during labor AND/OR delivery in liveborn infant",
#     "Gammaherpesviral mononucleosis",
#     "Pre-eclampsia or eclampsia with pre-existing hypertension - not delivered",
#     "Carotid sinus hypersensitivity",
#     "Carotid sinus syncope",
#     "Congenital cardiovascular disorders during pregnancy, childbirth and the puerperium",
#     "Venous complication in the puerperium",
#     "Fabry's disease",
#     "Hemopericardium",
#     "Ophthalmoplegic migraine",
#     "Acquired cardiac septal defect"
#   ]
# }
# ```
# [end chunk 5/5]
# [start chunk 1/5]
# ```json
# {
#   "acute disease of cardiovascular system": [
#     "True posterior myocardial infarction",
#     "Thrombosis of atrium, auricular appendage, and ventricle due to and following acute myocardial infarction"
#   ],
#   "aneurysm": [],
#   "cardiac arrhythmia": [],
#   "cardiovascular injury": [
#     "Postoperative cardiac complication",
#     "Injury of aorta"
#   ]
# }
# ```
# [end chunk 1/5]
#
# [start chunk 2/5]
# ```json
# {
#   "chronic disease of cardiovascular system": [
#     "Chronic constrictive pericarditis",
#     "Biventricular congestive heart failure",
#     "Dilated cardiomyopathy secondary to peripartum heart disease"
#   ],
#   "congenital anomaly of cardiovascular structure of trunk": [],
#   "congenital anomaly of cardiovascular system": [
#     "Dextrocardia",
#     "Congenital cardiovascular disorder during pregnancy - baby not yet delivered"
#   ],
#   "congenital vascular disorder": []
# }
# ```
# [end chunk 2/5]
#
# [start chunk 3/5]
# ```json
# {
#   "embolism": [],
#   "heart valve disorder": [
#     "Aortic stenosis, non-rheumatic",
#     "Rheumatic aortic stenosis with regurgitation",
#     "Rheumatic mitral stenosis with regurgitation"
#   ],
#   "hemorrhage of blood vessel": [],
#   "injury of blood vessel": [
#     "Injury of blood vessels of thorax",
#     "Injury of femoral artery"
#   ]
# }
# ```
# [end chunk 3/5]
#
# [start chunk 4/5]
# ```json
# {
#   "myocardial disease": [
#     "Myocardial ischemia"
#   ],
#   "thrombosis": [
#     "Intracranial venous thrombosis",
#     "Cerebral venous sinus thrombosis",
#     "Nonpyogenic thrombosis of intracranial venous sinus",
#     "Vertebral artery thrombosis"
#   ],
#   "thrombosis of blood vessel": [],
#   "vascular disease of abdomen": []
# }
# ```
# [end chunk 4/5]
#
# [start chunk 5/5]
# ```json
# {
#   "vascular disorder": [
#     "Renal artery stenosis",
#     "Temporal arteritis",
#     "Ascending aorta dilatation",
#     "Atherosclerosis of autologous vein bypass graft of limb",
#     "Arteriosclerosis of coronary artery bypass graft of transplanted heart",
#     "Primary necrotizing systemic vasculitis",
#     "Granulomatosis with polyangiitis with multisystem involvement",
#     "Cerebral amyloid angiopathy",
#     "Erythromelalgia",
#     "Retinal venous engorgement",
#     "Vulval varices"
#   ],
#   "vasculitis": [],
#   "venous varices": [],
#   "other": [
#     "Chronic gastrojejunal ulcer with hemorrhage",
#     "Near syncope",
#     "Pigmented purpuric lichenoid dermatitis of Gougerot and Blum",
#     "Maternal hypotension syndrome",
#     "Cardiac transplant rejection",
#     "Cardiac insufficiency during AND/OR resulting from a procedure",
#     "Gastric ulcer with hemorrhage and perforation",
#     "Gastric hemorrhage due to alcoholic gastritis",
#     "Anterior spinal artery compression syndrome",
#     "Cardiovascular syphilis",
#     "Hemicrania continua",
#     "Migraine without aura, not refractory",
#     "Adhesive pericarditis",
#     "Rupture of chordae tendineae",
#     "Abnormality of aortic arch branch",
#     "Pre-existing secondary hypertension complicating pregnancy, childbirth and puerperium",
#     "Malignant secondary renovascular hypertension",
#     "HELLP syndrome",
#     "Triple vessel disease of the heart"
#   ]
# }
# ```
# [end chunk 5/5]
# [start chunk 1/5]
# ```json
# {
#   "acute disease of cardiovascular system": [
#     "Thunderclap headache",
#     "Primary thunderclap headache",
#     "Subsequent ST segment elevation myocardial infarction",
#     "Severe pre-eclampsia with postnatal complication"
#   ],
#   "aneurysm": [],
#   "cardiac arrhythmia": [
#     "Atrial tachycardia",
#     "Permanent atrial fibrillation"
#   ],
#   "cardiovascular injury": [
#     "Injury of radial blood vessel",
#     "Injury of carotid artery",
#     "Injury of thoracic aorta",
#     "Injury of popliteal vessels",
#     "Injury of vein of trunk",
#     "Ulnar blood vessel injury",
#     "Digital blood vessel injury"
#   ]
# }
# ```
# [end chunk 1/5]
#
# [start chunk 2/5]
# ```json
# {
#   "chronic disease of cardiovascular system": [
#     "Chronic mixed headache syndrome",
#     "Benign hypertensive heart AND renal disease",
#     "Silent myocardial ischemia",
#     "Multi vessel coronary artery disease",
#     "Chronic deep venous thrombosis of internal jugular vein",
#     "Chronic thrombosis of subclavian vein"
#   ],
#   "congenital anomaly of cardiovascular structure of trunk": [],
#   "congenital anomaly of cardiovascular system": [
#     "Congenital insufficiency of pulmonary valve",
#     "Endocardial fibroelastosis"
#   ],
#   "congenital vascular disorder": []
# }
# ```
# [end chunk 2/5]
#
# [start chunk 3/5]
# ```json
# {
#   "embolism": [
#     "Air embolism",
#     "Obstetric blood-clot pulmonary embolism"
#   ],
#   "heart valve disorder": [
#     "Aortic valve calcification",
#     "Aortic valve sclerosis",
#     "Mechanical complication of heart valve prosthesis"
#   ],
#   "hemorrhage of blood vessel": []
# }
# ```
# [end chunk 3/5]
#
# [start chunk 4/5]
# ```json
# {
#   "injury of blood vessel": [
#     "Arterial laceration"
#   ],
#   "myocardial disease": [
#     "Sarcoid heart muscle disease",
#     "Myocarditis due to infectious agent",
#     "Cardiac sarcoidosis"
#   ],
#   "thrombosis": [
#     "Thrombophlebitis migrans",
#     "Postpartum deep phlebothrombosis"
#   ],
#   "thrombosis of blood vessel": [
#     "Occlusion and stenosis of posterior cerebral artery",
#     "Dissection of iliac artery"
#   ]
# }
# ```
# [end chunk 4/5]
#
# [start chunk 5/5]
# ```json
# {
#   "vascular disease of abdomen": [
#     "Varicocele"
#   ],
#   "vascular disorder": [
#     "Pulmonary hypertensive venous disease",
#     "Pulmonary hypertension due to lung disease and/or hypoxia",
#     "Pulmonary hypertension due to left heart disease",
#     "Persistent pulmonary hypertension of the newborn",
#     "Giant cell arteritis with polymyalgia rheumatica"
#   ],
#   "vasculitis": [
#     "Rheumatoid vasculitis"
#   ],
#   "venous varices": [],
#   "other": [
#     "Malignant tumor of heart",
#     "Primary malignant neoplasm of heart",
#     "Mechanical complication of aortic graft",
#     "Papillary muscle disorder",
#     "Hepatopulmonary syndrome",
#     "R.I.N.D. syndrome",
#     "Measles without complication",
#     "Cardiac insufficiency following cardiac surgery",
#     "Abdominal migraine"
#   ]
# }
# ```
# [end chunk 5/5]
# [start chunk 1/5]
# ```json
# {
#   "acute disease of cardiovascular system": [
#     "Acute rheumatic endocarditis",
#     "Idiopathic myocarditis",
#     "Acute and subacute infective endocarditis associated with another disorder"
#   ],
#   "aneurysm": [
#     "Pulmonary artery aneurysm",
#     "Intracranial aneurysm"
#   ],
#   "cardiac arrhythmia": [
#     "Premature atrial contraction",
#     "Re-entry ventricular arrhythmia",
#     "Nonsustained ventricular tachycardia",
#     "Atrial paroxysmal tachycardia",
#     "Junctional premature complex"
#   ],
#   "cardiovascular injury": [
#     "Injury of popliteal artery",
#     "Iliac blood vessel injury",
#     "Injury of common femoral artery",
#     "Injury to blood vessel of neck"
#   ],
#   "chronic disease of cardiovascular system": [
#     "Chronic thromboembolic pulmonary hypertension",
#     "Congestive heart failure due to left ventricular systolic dysfunction",
#     "Intermittent hypertension"
#   ]
# }
# ```
# [end chunk 1/5]
#
# [start chunk 2/5]
# ```json
# {
#   "congenital anomaly of cardiovascular structure of trunk": [
#     "Bulbus cordis and cardiac septal closure anomalies"
#   ],
#   "congenital anomaly of cardiovascular system": [
#     "Congenital abnormality of aortic valve cusp",
#     "Bicuspid cardiac valve",
#     "Abnormal number of cusps",
#     "Tricuspid valve stenosis with insufficiency"
#   ],
#   "congenital vascular disorder": [
# ...
#   ],
#   "thrombosis": [
#     "Deep venous thrombosis of pelvic vein",
#     "Recurrent deep vein thrombosis"
#   ],
#   "thrombosis of blood vessel": [
#     "Postpartum septic thrombophlebitis"
#   ],
#   "vascular disease of abdomen": [
#     "Aortoiliac atherosclerosis",
#     "Terminal aortic occlusion"
#   ]
# }
# ```
# [end chunk 4/5]
#
# [start chunk 5/5]
# ```json
# {
#   "vascular disorder": [
#     "Basilar artery stenosis",
#     "Vascular graft stenosis",
#     "Portal vein-hepatic artery fistula"
#   ],
#   "vasculitis": [
#     "Infective aortitis",
#     "Syphilitic aortitis"
#   ],
#   "venous varices": [
#     "Venous hypertension of lower limb"
#   ],
#   "other": [
#     "Arteriovenous malformation of kidney",
#     "Carotidynia",
#     "Heart-lung transplant failure and rejection",
#     "Puerperal cerebrovascular disorder - delivered with postnatal complication",
#     "Cardiac disorder due to typhoid fever",
#     "Coronary artery bypass graft occlusion",
#     "Pneumopericardium",
#     "Pericardial cyst",
#     "Closed fracture of T1-T6 level with anterior cord syndrome",
#     "Dissection of artery of upper extremity"
#   ]
# }
# ```
# [end chunk 5/5]
# [start chunk 1/5]
# ```json
# {
#   "acute disease of cardiovascular system": [
#     "Acute Chagas' disease with heart involvement",
#     "Moderate laceration of heart with hemopericardium",
#     "Old anterior myocardial infarction"
#   ],
#   "aneurysm": [
#     "Left ventricular aneurysm"
#   ],
#   "cardiac arrhythmia": [
#     "Sustained ventricular tachycardia",
#     "Ectopic atrial tachycardia",
#     "Symptomatic sinus bradycardia",
#     "AV-junctional (nodal) bradycardia"
#   ],
#   "cardiovascular injury": [
#     "Moderate laceration of heart with hemopericardium"
#   ],
#   "chronic disease of cardiovascular system": [
#     "Congestive heart failure stage C",
#     "Cardiorenal syndrome",
#     "Senile cardiac amyloidosis",
#     "Primary restrictive cardiomyopathy"
#   ]
# }
# ```
# [end chunk 1/5]
#
# [start chunk 2/5]
# ```json
# {
#   "congenital anomaly of cardiovascular structure of trunk": [
#     "Congenital phlebectasia"
#   ],
#   "congenital anomaly of cardiovascular system": [
#     "Arterial tortuosity syndrome"
#   ],
#   "congenital vascular disorder": [
#     "Congenital phlebectasia"
#   ],
#   "embolism": [
#     "Amniotic fluid pulmonary embolism - delivered",
#     "Amniotic fluid pulmonary embolism with antenatal complication"
#   ],
#   "heart valve disorder": [
#     "Non-rheumatic aortic valve stenosis with regurgitation",
#     "Prosthetic cardiac valve displacement"
#   ]
# }
# ```
# [end chunk 2/5]
#
# [start chunk 3/5]
# ```json
# {
#   "hemorrhage of blood vessel": [
#     "Choroidal hemorrhage and rupture"
#   ],
#   "injury of blood vessel": [
#     "Injury of axillary vein",
#     "Injury of pulmonary vein",
#     "Injury of deep plantar blood vessel",
#     "Injury of brachial vein",
#     "Injury of hepatic vein",
#     "Injury of dorsal vein of foot",
#     "Injury of inferior mesenteric vein",
#     "Minor laceration of carotid artery",
#     "Injury of posterior tibial vein",
#     "Injury of primary branch of superior mesenteric artery",
#     "Minor laceration of vertebral artery",
#     "Injury of hypogastric artery"
#   ],
#   "myocardial disease": [
#     "Diphtheritic myocarditis"
#   ]
# }
# ```
# [end chunk 3/5]
#
# [start chunk 4/5]
# ```json
# {
#   "thrombosis": [
#     "Thrombosis of cerebral veins",
#     "Thrombosis of internal jugular vein",
#     "Superior mesenteric vein thrombosis",
#     "Thrombosis of superior vena cava"
#   ],
#   "thrombosis of blood vessel": [
#     "Thrombosis of cerebral veins",
#     "Thrombosis of internal jugular vein",
#     "Superior mesenteric vein thrombosis",
#     "Thrombosis of superior vena cava"
#   ],
#   "vascular disease of abdomen": [
#     "Superior mesenteric vein thrombosis",
#     "Injury of inferior mesenteric vein"
#   ],
#   "vascular disorder": [
#     "Peripheral arterial insufficiency",
#     "Upper limb ischemia",
#     "Femoral artery occlusion"
#   ]
# }
# ```
# [end chunk 4/5]
#
# [start chunk 5/5]
# ```json
# {
#   "vasculitis": [
#     "Histoplasma capsulatum with pericarditis"
#   ],
#   "venous varices": [
#     "Generalized essential telangiectasia"
#   ],
#   "other": [
#     "Pre-existing hypertensive heart and chronic kidney disease in mother complicating pregnancy",
#     "Chronic nephritic syndrome, diffuse endocapillary proliferative glomerulonephritis",
#     "Pleuropericardial cyst",
#     "Rupture of chordae tendinae due to and following acute myocardial infarction",
#     "Pre-existing hypertensive heart and renal disease complicating pregnancy, childbirth and the puerperium",
#     "Migraine variants, not intractable",
#     "Cardiorespiratory arrest"
#   ]
# }
# ```
# [end chunk 5/5]
# [start chunk 1/5]
# ```json
# {
#   "acute disease of cardiovascular system": [
#     "Acute non-Q wave infarction",
#     "Acute anterior ST segment elevation myocardial infarction",
#     "Silent myocardial infarction"
#   ],
#   "aneurysm": [
#     "Femoral false aneurysm"
#   ],
#   "cardiac arrhythmia": [
#     "Torsades de pointes",
#     "Lone atrial fibrillation",
#     "Congenital long QT syndrome"
#   ],
#   "cardiovascular injury": [
#     "Major laceration of heart with hemopericardium"
#   ]
# }
# ```
# [end chunk 1/5]
#
# [start chunk 2/5]
# ```json
# {
#   "chronic disease of cardiovascular system": [
#     "Multi-infarct dementia with depression",
#     "Pre-existing hypertension complicating AND/OR reason for care during pregnancy",
#     "Atherosclerotic renal artery stenosis"
#   ],
#   "congenital anomaly of cardiovascular structure of trunk": [
#     "Congenital hypoplasia of aorta"
#   ],
#   "congenital anomaly of cardiovascular system": [
#     "Abnormality of common atrioventricular valve in atrioventricular septal defect"
#   ],
#   "congenital vascular disorder": [
#     "Congenital atresia of pulmonary artery"
#   ]
# }
# ```
# [end chunk 2/5]
#
# [start chunk 3/5]
# ```json
# {
#   "embolism": [
#     "Amniotic fluid embolism in childbirth",
#     "Pyemic and septic embolism in pregnancy",
#     "Legal termination of pregnancy complicated by embolism",
#     "Amniotic fluid pulmonary embolism with postnatal complication"
#   ],
#   "heart valve disorder": [
#     "Critical stenosis of aortic valve"
#   ],
#   "hemorrhage of blood vessel": [
#     "Massive umbilical hemorrhage of newborn"
#   ],
#   "injury of blood vessel": [
#     "Minor laceration of external jugular vein",
#     "Major laceration of carotid artery",
#     "Major laceration of vertebral artery",
#     "Major laceration of internal jugular vein",
#     "Minor laceration of internal jugular vein",
#     "Injury of multiple blood vessels of thorax",
#     "Injury of anterior tibial vein",
#     "Injury of ovarian vein"
#   ]
# }
# ```
# [end chunk 3/5]
#
# [start chunk 4/5]
# ```json
# {
#   "myocardial disease": [
#     "Tachycardia-induced cardiomyopathy"
#   ],
#   "thrombosis": [
#     "Thrombosis of inferior vena cava",
#     "Saphenous vein thrombophlebitis",
#     "Thrombophlebitis of pelvic vein",
#     "Splenic vein thrombosis",
#     "Phlebitis of iliac vein"
#   ],
#   "thrombosis of blood vessel": [
#     "Ischemic hand",
#     "Ischemic foot"
#   ],
#   "vascular disease of abdomen": [
#     "Leriche's syndrome"
#   ]
# }
# ```
# [end chunk 4/5]
#
# [start chunk 5/5]
# ```json
# {
#   "vascular disorder": [
#     "Right cardiac ventricular dilatation",
#     "Associated pulmonary arterial hypertension",
#     "Renal hypertension complicating pregnancy, childbirth and the puerperium"
#   ],
#   "vasculitis": [
#     "Juvenile polyarteritis"
#   ],
#   "venous varices": [],
#   "other": [
#     "Calciphylaxis",
#     "Senile hemangioma of lip",
#     "Cerebral autosomal dominant arteriopathy with subcortical infarcts and leukoencephalopathy",
#     "Meningococcal pericarditis",
#     "Coxsackie endocarditis",
#     "Cardiac complications of anesthesia during labor and delivery",
#     "Cardiac arrest due to miscarriage",
#     "Pre-eclampsia added to pre-existing hypertension",
#     "Angiofibroma"
#   ]
# }
# ```
# [end chunk 5/5]
# [start chunk 1/5]
# ```json
# {
#   "acute disease of cardiovascular system": [
#     "Acute ST segment elevation myocardial infarction of inferior wall",
#     "Cardiac complication of anesthesia during the puerperium",
#     "Meningococcal myocarditis",
#     "Myocarditis due to scarlet fever",
#     "Post-pericardiotomy syndrome"
#   ],
#   "aneurysm": [],
#   "cardiac arrhythmia": [
#     "Arrhythmogenic right ventricular dysplasia",
#     "Sinoatrial block"
#   ],
#   "cardiovascular injury": [
#     "Injury of branch of celiac axis",
#     "Injury of internal iliac vein",
#     "Injury of ovarian artery",
#     "Injury of uterine vein"
#   ],
#   "chronic disease of cardiovascular system": [
#     "Multi-infarct dementia with delusions",
#     "Pre-existing hypertensive heart and chronic kidney disease in mother complicating childbirth",
#     "Low output heart failure"
#   ]
# }
# ```
# [end chunk 1/5]
#
# [start chunk 2/5]
# ```json
# {
#   "congenital anomaly of cardiovascular structure of trunk": [],
#   "congenital anomaly of cardiovascular system": [
#     "Congenital hypoplasia of pulmonary artery"
#   ],
#   "congenital vascular disorder": [],
#   "embolism": [
#     "Complete miscarriage with embolism",
#     "Failed attempted termination of pregnancy complicated by embolism",
#     "Illegal termination of pregnancy complicated by embolism",
#     "Air embolism in childbirth"
#   ],
#   "heart valve disorder": [
#     "Tricuspid valve prolapse",
#     "Rheumatic heart valve failure",
#     "Prosthetic valve endocarditis"
#   ]
# }
# ```
# [end chunk 2/5]
#
# [start chunk 3/5]
# ```json
# {
#   "hemorrhage of blood vessel": [
#     "Fetal blood loss from ruptured cord"
#   ],
#   "injury of blood vessel": [
#     "Major laceration of external jugular vein"
#   ],
#   "myocardial disease": [
#     "Histoplasma duboisii with pericarditis",
#     "Gonococcal pericarditis",
#     "Syphilitic pericarditis"
#   ],
#   "thrombosis": [
#     "Thrombosis of cavernous venous sinus",
#     "Arteriovenous graft thrombosis"
#   ],
#   "thrombosis of blood vessel": [
#     "Popliteal artery occlusion"
#   ]
# }
# ```
# [end chunk 3/5]
#
# [start chunk 4/5]
# ```json
# {
#   "vascular disease of abdomen": [
#     "Stenosis of abdominal aorta",
#     "Dissection of proximal aorta",
#     "Dissection of distal aorta"
#   ],
#   "vascular disorder": [
#     "Vascular thoracic outlet syndrome",
#     "Steal syndrome of upper limb",
#     "Steal syndrome of hand",
#     "Vibration syndrome",
#     "Vibration white finger"
#   ],
#   "vasculitis": [
#     "Syphilitic cerebral arteritis"
#   ],
#   "venous varices": []
# }
# ```
# [end chunk 4/5]
#
# [start chunk 5/5]
# ```json
# {
#   "other": [
#     "Pulmonary vein stenosis",
#     "Subclavian vein stenosis",
#     "Persistent hematuria co-occurrent and due to diffuse endocapillary proliferative glomerulonephritis",
#     "Rubella encephalomyelitis",
#     "Maternal rubella in the puerperium - baby delivered during current episode of care",
#     "Measles with intestinal complications",
#     "Ischemic toe",
#     "Gonococcal endocarditis",
#     "Neoplasm of uncertain behavior of blood vessel",
#     "Open fracture of C1-C4 level with anterior cord syndrome",
#     "Moderate proteinuric hypertension of pregnancy"
#   ]
# }
# ```
# [end chunk 5/5]
# [start chunk 1/5]
# ```json
# {
#   "acute disease of cardiovascular system": [
#     "Acute anteroseptal myocardial infarction",
#     "Acute myocardial infarction of atrium",
#     "Low cardiac output syndrome",
#     "Acute deep venous thrombosis of pelvic vein"
#   ],
#   "aneurysm": [
#     "Mycotic aneurysm"
#   ],
#   "cardiac arrhythmia": [
#     "Re-entrant atrioventricular node tachycardia",
#     "Nonsustained paroxysmal ventricular tachycardia",
#     "Ventricular pre-excitation",
#     "Fetal bradycardia"
#   ],
#   "cardiovascular injury": [
#     "Injury of multiple blood vessels of upper extremity",
#     "Injury of innominate artery",
#     "Injury of multiple blood vessels at ankle and foot level"
#   ]
# }
# ```
# [end chunk 1/5]
#
# [start chunk 2/5]
# ```json
# {
#   "chronic disease of cardiovascular system": [
#     "Right ventricular systolic dysfunction",
#     "Renal hypertension complicating pregnancy, childbirth and the puerperium - not delivered",
#     "Hypertension associated with transplantation"
#   ],
#   "congenital anomaly of cardiovascular structure of trunk": [
#     "Ebstein's anomaly of common atrioventricular valve"
#   ],
#   "congenital anomaly of cardiovascular system": [
#     "Neonatal cyanosis"
#   ],
#   "congenital vascular disorder": [
#     "Kartagener syndrome",
#     "Venous-lymphatic malformation"
#   ]
# }
# ```
# [end chunk 2/5]
#
# [start chunk 3/5]
# ```json
# {
#   "embolism": [
#     "Pyemic and septic embolism in childbirth",
#     "Pulmonary fat embolism"
#   ],
#   "heart valve disorder": [
#     "Mitral valve vegetations",
#     "Aortic valve vegetations",
#     "Prosthetic cardiac valve thrombosis"
#   ],
#   "hemorrhage of blood vessel": [
#     "Gastric hemorrhage due to angiodysplasia of stomach"
#   ],
#   "injury of blood vessel": [
#     "Rupture iliac artery"
#   ]
# }
# ```
# [end chunk 3/5]
#
# [start chunk 4/5]
# ```json
# {
#   "myocardial disease": [
#     "Mumps myocarditis"
#   ],
#   "thrombosis": [
#     "Thrombophlebitis of breast",
#     "Phlebolithiasis",
#     "Prosthetic cardiac valve thrombosis"
#   ],
#   "thrombosis of blood vessel": [
#     "Thrombosis of retinal artery",
#     "Thrombosis transverse sinus",
#     "Postoperative deep vein thrombosis"
#   ],
#   "vascular disease of abdomen": [
#     "Vascular ectasia of colon"
#   ]
# }
# ```
# [end chunk 4/5]
#
# [start chunk 5/5]
# ```json
# {
#   "vascular disorder": [
#     "Portal systemic vascular shunt disorder",
#     "Arteriovenous fistula infection"
#   ],
#   "vasculitis": [
#     "Urticarial vasculitis",
#     "Cogan's syndrome"
#   ],
#   "venous varices": [
#     "Telangiectasia of skin of face"
#   ],
#   "other": [
#     "Arteriovenous hemangioma",
#     "Systemic lupus erythematosus encephalitis",
#     "Hemangiopericytoma",
#     "Femoral popliteal occlusion",
#     "Right atrial dilatation",
#     "Electromechanical dissociation",
#     "Induced termination of pregnancy complicated by cardiac arrest",
#     "Cardiac arrest due to incomplete miscarriage",
#     "Cardiac arrest due to failed attempted abortion",
#     "Left coronary artery occlusion"
#   ]
# }
# ```
# [end chunk 5/5]
# [start chunk 1/4]
# ```json
# {
#   "acute disease of cardiovascular system": [
#     "Exacerbation of congestive heart failure",
#     "Accelerated coronary artery disease in transplanted heart"
#   ],
#   "aneurysm": [],
#   "cardiac arrhythmia": [
#     "Junctional escape beats",
#     "AV node arrhythmia",
#     "Diffuse intraventricular block"
#   ],
#   "cardiovascular injury": [
#     "Injury of multiple blood vessels at forearm level",
#     "Injury of multiple blood vessels at lower leg level",
#     "Injury of multiple blood vessels at neck level",
#     "Injury of subclavian artery"
#   ],
#   "chronic disease of cardiovascular system": [
#     "Pre-existing hypertension complicating AND/OR reason for care during childbirth"
#   ]
# }
# ```
# [end chunk 1/4]
#
# [start chunk 2/4]
# ```json
# {
#   "congenital anomaly of cardiovascular structure of trunk": [
#     "Right ventricular outflow tract obstruction",
#     "Rupture of interventricular septum",
#     "Interventricular cardiac septal hypertrophy"
#   ],
#   "congenital anomaly of cardiovascular system": [
#     "Scimitar syndrome",
#     "Fetal pericardial effusion"
#   ],
#   "congenital vascular disorder": [
#     "Congenital stenosis of pulmonary veins"
#   ],
#   "embolism": [],
#   "heart valve disorder": [
#     "Valvular cardiomyopathy"
#   ]
# }
# ```
# [end chunk 2/4]
#
# [start chunk 3/4]
# ```json
# {
#   "hemorrhage of blood vessel": [
#     "Vascular graft hemorrhage"
#   ],
#   "injury of blood vessel": [],
#   "myocardial disease": [
#     "Hypertrophic cardiomegaly",
#     "Primary idiopathic hypertrophic cardiomyopathy"
#   ],
#   "thrombosis": [
#     "Celiac artery thrombosis"
#   ],
#   "thrombosis of blood vessel": [
#     "Cerebral venous thrombosis of cortical vein"
#   ]
# }
# ```
# [end chunk 3/4]
#
# [start chunk 4/4]
# ```json
# {
#   "vascular disease of abdomen": [
#     "Abdominal angina"
#   ],
#   "vascular disorder": [
#     "Popliteal entrapment syndrome",
#     "Hepatic artery stenosis",
#     "Dural arteriovenous fistula"
#   ],
#   "vasculitis": [],
#   "venous varices": [
#     "Bleeding gastric varices"
#   ],
#   "other": [
#     "Lyme carditis",
#     "Subcortical leukoencephalopathy",
#     "Athlete's heart",
#     "Erythrocyanosis",
#     "Exertional hypotension",
#     "Fahr's syndrome"
#   ]
# }
# ```
# [end chunk 4/4]

# %% [markdown]
# # combine json files

# %%
import re

# Split the result string by triple backticks and filter out the non-JSON content
chunks = re.findall(r'```json\n(.*?)\n```', result_chunked, re.DOTALL)

# Initialize an empty list to store the data
json_data = []

# Process each chunk and parse the valid JSON
for chunk in chunks:
    try:
        # Parse the JSON string into a Python dictionary
        json_obj = json.loads(chunk)
        json_data.append(json_obj)
    except json.JSONDecodeError as e:
        print(f"Error decoding JSON: {e}")
        print("Attempting manual cleanup of chunk:", chunk[:100])  # Print first 100 characters for debugging

# Now, save each parsed chunk as a separate JSON file
for i, data in enumerate(json_data, start=1):
    with open(f'CV_Grouping_chunk_{i}.json', 'w') as json_file:
        json.dump(data, json_file, indent=2)

print("JSON files have been saved.")
# Out:
# JSON files have been saved.

# %%
def merge_json_files(directory="."):
    # Pattern to match your JSON files
    pattern = os.path.join(directory, "CV_Grouping_chunk_*.json")
    json_files = glob.glob(pattern)
    
    merged_data = {}

    for fpath in json_files:
        with open(fpath, 'r', encoding='utf-8') as f:
            data = json.load(f)
            # Merge dictionaries
            for key, value_list in data.items():
                # If key already exists, extend the list
                if key in merged_data:
                    # Combine the lists, optionally remove duplicates
                    merged_data[key].extend(value_list)
                    # Remove duplicates while preserving order
                    seen = set()
                    merged_data[key] = [x for x in merged_data[key] if not (x in seen or seen.add(x))]
                else:
                    merged_data[key] = value_list

    return merged_data

all_data = merge_json_files()
# Print or save merged results
print(json.dumps(all_data, indent=2))
# Out:
# {
#   "vascular disorder": [
#     "Vascular hemostatic disease",
#     "Aortic thromboembolism",
#     "Carotid artery stenosis",
#     "Carotid artery occlusion",
#     "Stenosis of precerebral artery",
#     "Vertebral artery obstruction",
#     "Retinal artery occlusion",
#     "Central retinal vein occlusion with macular edema",
#     "Transient arterial retinal occlusion",
#     "Telangiectasia disorder",
#     "Cutaneous vascular malformation",
#     "Angiodysplasia of colon",
#     "Male genital organ vascular diseases",
#     "Carotid atherosclerosis",
#     "Dilatation of pulmonary artery",
#     "Brainstem stroke syndrome",
#     "Pulmonary hypertensive venous disease",
#     "Pulmonary hypertension due to lung disease and/or hypoxia",
#     "Pulmonary hypertension due to left heart disease",
#     "Persistent pulmonary hypertension of the newborn",
#     "Giant cell arteritis with polymyalgia rheumatica",
#     "Polyarteritis",
#     "Polyarteritis nodosa",
#     "Cerebral vasculitis",
#     "Arterial steal syndrome",
#     "Carotid artery syndrome hemispheric",
#     "Vertebrobasilar artery syndrome",
#     "Orthostatic hypotension",
#     "Venous hypertension",
#     "Arterial malformation",
#     "Ectasia of thoracic aorta",
#     "Cerebral arteriosclerosis",
#     "Cerebral atherosclerosis",
#     "Systemic vein obstruction",
#     "Precerebral arterial occlusion",
#     "Bypass graft mechanical complications",
#     "Peripheral ischemia",
#     "Left carotid artery stenosis",
#     "Right carotid artery stenosis",
#     "Venous stenosis",
#     "Peripheral arterial insufficiency",
#     "Upper limb ischemia",
#     "Femoral artery occlusion",
#     "Hepatic artery stenosis",
#     "Secondary hypertension",
#     "Cerebral ischemia",
#     "Renal vascular disorder",
#     "Stenosis of artery",
#     "Raynaud's disease",
#     "Nephrosclerosis",
#     "Generalized atherosclerosis",
#     "Peripheral vascular complication",
#     "Vascular disease of the skin",
#     "Basilar artery stenosis",
#     "Vascular graft stenosis",
#     "Portal vein-hepatic artery fistula",
#     "Obstruction of precerebral artery",
#     "Carotid artery obstruction",
#     "Peripheral vascular disorder due to diabetes mellitus",
#     "Peripheral circulatory disorder due to type 2 diabetes mellitus",
#     "Peripheral venous insufficiency",
#     "Autoimmune vasculitis",
#     "Vascular insufficiency of limb",
#     "Atherosclerosis of bypass graft of limb",
#     "Arteriovenous fistula",
#     "Vascular complication of medical care",
#     "Penile arterial insufficiency",
#     "Arteriosclerotic gangrene",
#     "Renovascular hypertension",
#     "Maternal hypertension",
#     "Transient hypertension of pregnancy - delivered",
#     "Atherosclerosis of right carotid artery",
#     "Atherosclerotic occlusive disease",
#     "Atherosclerosis of left carotid artery",
#     "Anterior spinal and vertebral artery compression syndromes",
#     "Popliteal entrapment syndrome",
#     "Dural arteriovenous fistula",
#     "Pulmonary arteriovenous malformation",
#     "Pulmonary artery aneurysm",
#     "Central retinal vein occlusion with neovascularization",
#     "Branch retinal vein occlusion with neovascularization",
#     "Vascular calcification",
#     "Senile angioma",
#     "Retinal telangiectasia",
#     "Microaneurysm of retinal artery",
#     "Vertebral artery syndrome",
#     "Cerebral vasoconstriction syndrome",
#     "Portal systemic vascular shunt disorder",
#     "Arteriovenous fistula infection",
#     "Asymptomatic coronary heart disease",
#     "Malignant hypertensive heart AND renal disease",
#     "Single coronary vessel disease",
#     "Iliac artery stenosis",
#     "Vascular graft occlusion",
#     "Occlusion of lower limb artery",
#     "Internal jugular vein stenosis",
#     "Multiple AND bilateral precerebral artery stenosis",
#     "Dissection of cerebral artery",
#     "CVA - cerebrovascular accident due to cerebral artery occlusion",
#     "Right cardiac ventricular dilatation",
#     "Associated pulmonary arterial hypertension",
#     "Renal hypertension complicating pregnancy, childbirth and the puerperium",
#     "Iliac vein compression syndrome",
#     "Superior vena cava syndrome",
#     "Stenosis of lower limb artery",
#     "Critical lower limb ischemia",
#     "Stricture of artery",
#     "Coronary occlusion",
#     "Vascular disorder",
#     "Vascular degeneration",
#     "Arteriosclerotic vascular disease",
#     "Atherosclerosis of artery",
#     "Disease of non-coronary systemic artery",
#     "Coronary arteriosclerosis",
#     "Coronary atherosclerosis",
#     "Atherosclerosis of coronary artery without angina pectoris",
#     "Vascular insufficiency",
#     "Vascular thoracic outlet syndrome",
#     "Steal syndrome of upper limb",
#     "Steal syndrome of hand",
#     "Vibration syndrome",
#     "Vibration white finger",
#     "Peripheral circulatory disorder due to type 1 diabetes mellitus",
#     "Arterial insufficiency",
#     "Arteriosclerosis of artery of extremity",
#     "Posterior cerebral artery syndrome",
#     "Anterior cerebral artery syndrome",
#     "Vertebral artery occlusion",
#     "Vertebral artery stenosis",
#     "Small vessel cerebrovascular disease",
#     "Calcific coronary arteriosclerosis",
#     "Limb ischemia",
#     "Renal artery stenosis",
#     "Temporal arteritis",
#     "Ascending aorta dilatation",
#     "Atherosclerosis of autologous vein bypass graft of limb",
#     "Arteriosclerosis of coronary artery bypass graft of transplanted heart",
#     "Primary necrotizing systemic vasculitis",
#     "Granulomatosis with polyangiitis with multisystem involvement",
#     "Cerebral amyloid angiopathy",
#     "Erythromelalgia",
#     "Retinal venous engorgement",
#     "Vulval varices",
#     "Reversible cerebral vasoconstriction syndrome",
#     "Atherosclerosis of bypass graft of lower limb",
#     "Calcification of coronary artery",
#     "Pre-existing hypertensive heart disease complicating pregnancy, childbirth and the puerperium",
#     "Transient hypertension of pregnancy - delivered with postnatal complication",
#     "Pulmonary hypertension",
#     "Peripheral arterial occlusive disease",
#     "Occlusion of artery",
#     "Retinal vascular disorder"
#   ],
#   "vasculitis": [
#     "Retinal vasculitis",
#     "Necrotizing vasculitis",
#     "Cerebral arteritis",
#     "Capillaritis",
#     "Rheumatoid vasculitis",
#     "Cerebral vasculitis",
#     "Carditis",
#     "Endocarditis",
#     "Endocardial disease",
#     "Systemic vasculitis",
#     "Arteritis",
#     "Infective aortitis",
#     "Syphilitic aortitis",
#     "Vasculitis",
#     "Phlebitis",
#     "Henoch-Sch\u00f6nlein purpura",
#     "Hypersensitivity angiitis",
#     "Eosinophilic granulomatosis with polyangiitis",
#     "Vasculitis of the skin",
#     "Aortitis",
#     "Urticarial vasculitis",
#     "Cogan's syndrome",
#     "Rheumatoid arteritis",
#     "Histoplasma capsulatum with pericarditis",
#     "Juvenile polyarteritis",
#     "Small vessel vasculitis",
#     "Syphilitic cerebral arteritis",
#     "Antineutrophil cytoplasmic antibody positive vasculitis",
#     "Granulomatosis with polyangiitis",
#     "Lyme carditis",
#     "Behcet's syndrome",
#     "Acute febrile mucocutaneous lymph node syndrome",
#     "Livedoid vasculitis",
#     "Diffuse endocapillary proliferative glomerulonephritis",
#     "Gonococcal heart disease",
#     "Phlebitis of lower limb vein"
#   ],
#   "venous varices": [
#     "Varicose veins of lower extremity with inflammation",
#     "Simple varicose veins",
#     "Genital varices in pregnancy",
#     "Venous hypertension of lower limb",
#     "Varicose veins of lower extremity",
#     "Varicose veins of lower extremity without ulcer AND without inflammation",
#     "Thrombophlebitis of superficial veins of lower extremity",
#     "Thrombophlebitis of upper extremities",
#     "Sublingual varices",
#     "Bleeding gastric varices",
#     "Gastric varices",
#     "Telangiectasia of skin of face",
#     "Generalized essential telangiectasia",
#     "Esophageal varices without bleeding",
#     "Varicose veins of lower extremity with ulcer AND inflammation",
#     "Venous varices",
#     "Trunk varices",
#     "Pelvic varices",
#     "Hemorrhoids",
#     "Venous lake"
#   ],
#   "other": [
#     "Multi-infarct dementia",
#     "Postcardiotomy syndrome",
#     "Kyphoscoliotic heart disease",
#     "Maternal hypotension syndrome - delivered",
#     "Abnormal fetal heart beat noted before labor in liveborn infant",
#     "Ophthalmic migraine",
#     "Post infarct angina",
#     "Senile purpura",
#     "Vascular lesion of cord",
#     "Embolic stroke",
#     "Cardiac arrest as a complication of care",
#     "Peripheral arteriovenous malformation",
#     "Abnormal fetal heart beat first noted during labor AND/OR delivery in liveborn infant",
#     "Gammaherpesviral mononucleosis",
#     "Pre-eclampsia or eclampsia with pre-existing hypertension - not delivered",
#     "Carotid sinus hypersensitivity",
#     "Carotid sinus syncope",
#     "Congenital cardiovascular disorders during pregnancy, childbirth and the puerperium",
#     "Venous complication in the puerperium",
#     "Fabry's disease",
#     "Hemopericardium",
#     "Ophthalmoplegic migraine",
#     "Acquired cardiac septal defect",
#     "Malignant tumor of heart",
#     "Primary malignant neoplasm of heart",
#     "Mechanical complication of aortic graft",
#     "Papillary muscle disorder",
#     "Hepatopulmonary syndrome",
#     "R.I.N.D. syndrome",
#     "Measles without complication",
#     "Cardiac insufficiency following cardiac surgery",
#     "Abdominal migraine",
#     "Benign essential hypertension complicating pregnancy, childbirth and the puerperium with postnatal complication",
#     "Solitary pulmonary hypertension",
#     "Neonatal hypertension",
#     "Postpartum pregnancy-induced hypertension",
#     "Maternal hypotension syndrome with antenatal problem",
#     "Eclampsia in pregnancy",
#     "Hypoplasia of aorta",
#     "Menstrual status migrainosus",
#     "Left ventricular cardiac dysfunction",
#     "Type 2 diabetes mellitus with peripheral angiopathy",
#     "Anterior cord syndrome",
#     "Perinatal cyanotic attacks",
#     "Neoplasm of heart",
#     "Hypertension secondary to endocrine disorder",
#     "Phlebitis of the femoral vein",
#     "Acquired arteriovenous fistula",
#     "Pulmonary artery stenosis",
#     "Endocarditis associated with another disorder",
#     "Idiopathic hypotension",
#     "Congestive rheumatic heart failure",
#     "Hemangioma of intracranial structure",
#     "Benign essential hypertension complicating pregnancy, childbirth and the puerperium",
#     "Hemiplegic migraine",
#     "Capillary hemangioma",
#     "Complicated migraine",
#     "Ophthalmoplegic migraine, refractory",
#     "Chronic gastric ulcer with hemorrhage and with obstruction",
#     "Gastric hemorrhage due to chronic superficial gastritis",
#     "Spider nevus",
#     "Choroidal retinal neovascularization",
#     "Anterior cord syndrome of thoracic spinal cord",
#     "Maternal hypotension syndrome - delivered with postnatal problem",
#     "Obstetrical air embolism",
#     "Neonatal cerebral ischemia",
#     "Rheumatic chorea with heart involvement",
#     "Diastolic hypertension",
#     "Labile hypertension due to being in a clinical environment",
#     "Hemangioma of liver",
#     "Myopic choroidal neovascularization",
#     "Strawberry nevus of skin",
#     "Anterior cord syndrome of cervical spinal cord",
#     "Rubella in mother complicating pregnancy, childbirth AND/OR puerperium",
#     "Capillary malformation",
#     "Puerperal cerebrovascular disorder with antenatal complication",
#     "Puerperal cerebrovascular disorder with postnatal complication",
#     "Atypical angina",
#     "Pulmonary blood vessel injury",
#     "Aortic bifurcation syndrome",
#     "Left bundle branch block",
#     "Right bundle branch block",
#     "Partial atrioventricular block",
#     "Complete atrioventricular block",
#     "Retinal vascular occlusion",
#     "Hypertension in the obstetric context",
#     "Pre-existing hypertension in obstetric context",
#     "Refractory migraine without aura",
#     "Rubella in pregnancy",
#     "Transient hypertension of pregnancy - not delivered",
#     "Migraine aura without headache",
#     "Vascular lesions of cord - delivered",
#     "Fistula of artery",
#     "Dissection of artery of lower limb",
#     "Phlebitis of deep veins of lower extremity",
#     "Deep thrombophlebitis",
#     "Thrombophlebitis of deep veins of lower extremity",
#     "Heritable pulmonary arterial hypertension",
#     "Status migrainosus",
#     "Valvular endocarditis",
#     "Multiple and bilateral precerebral arterial occlusion",
#     "Left heart failure",
#     "Transformed migraine",
#     "Chronic intractable migraine without aura",
#     "Arteriovenous malformation of kidney",
#     "Carotidynia",
#     "Heart-lung transplant failure and rejection",
#     "Puerperal cerebrovascular disorder - delivered with postnatal complication",
#     "Cardiac disorder due to typhoid fever",
#     "Coronary artery bypass graft occlusion",
#     "Pneumopericardium",
#     "Pericardial cyst",
#     "Closed fracture of T1-T6 level with anterior cord syndrome",
#     "Dissection of artery of upper extremity",
#     "Low blood pressure",
#     "Old myocardial infarction",
#     "Dilatation of aorta",
#     "Transient cerebral ischemia",
#     "Disease of circulatory system complicating pregnancy childbirth and puerperium",
#     "Intraventricular conduction defect",
#     "Bundle branch block",
#     "Migraine without aura",
#     "Venous complication of pregnancy and/or the puerperium",
#     "Venous insufficiency of leg",
#     "Secondary venous insufficiency of leg",
#     "Postthrombotic syndrome",
#     "Heart disease in mother complicating pregnancy, childbirth AND/OR puerperium",
#     "Mallory-Weiss syndrome",
#     "Phlebitis of superficial veins of lower extremity",
#     "Menstrual migraine",
#     "Neonatal cardiovascular disorder",
#     "Cardiac complication",
#     "Low blood pressure reading",
#     "Neonatal dysrhythmia",
#     "Bacterial infectious disease of heart",
#     "Bacterial endocarditis",
#     "Subacute endocarditis",
#     "Acute and subacute endocarditis",
#     "Subacute bacterial endocarditis",
#     "Atherosclerosis of arteries of the extremities",
#     "Dissection of thoracic aorta",
#     "Peripheral angiopathy due to diabetes mellitus",
#     "Post-infarction ventricular septal defect",
#     "Lower limb ischemia",
#     "Port-wine stain of skin",
#     "Labile essential hypertension",
#     "Pre-eclampsia or eclampsia with pre-existing hypertension - delivered with postnatal complication",
#     "Maternal rubella during pregnancy - baby delivered",
#     "Angina, class II",
#     "Right atrial enlargement",
#     "Cardiac ventricular dilatation",
#     "Erythema elevatum diutinum",
#     "Obstetrical cardiac complication of anesthesia AND/OR sedation",
#     "Completed stroke",
#     "Transient hypertension of pregnancy with postnatal complication",
#     "Closed fracture of C1-C4 level with anterior cord syndrome",
#     "Mechanical complication of vena cava umbrella",
#     "Lyme carditis",
#     "Subcortical leukoencephalopathy",
#     "Athlete's heart",
#     "Erythrocyanosis",
#     "Exertional hypotension",
#     "Fahr's syndrome",
#     "Benign neoplasm of heart",
#     "Migraine with persistent visual aura",
#     "Rubella arthritis",
#     "Hemangioma of skin",
#     "Dissection of coronary artery",
#     "Arteriovenous hemangioma",
#     "Systemic lupus erythematosus encephalitis",
#     "Hemangiopericytoma",
#     "Femoral popliteal occlusion",
#     "Right atrial dilatation",
#     "Electromechanical dissociation",
#     "Induced termination of pregnancy complicated by cardiac arrest",
#     "Cardiac arrest due to incomplete miscarriage",
#     "Cardiac arrest due to failed attempted abortion",
#     "Left coronary artery occlusion",
#     "Pre-existing hypertensive heart and chronic kidney disease in mother complicating pregnancy",
#     "Chronic nephritic syndrome, diffuse endocapillary proliferative glomerulonephritis",
#     "Pleuropericardial cyst",
#     "Rupture of chordae tendinae due to and following acute myocardial infarction",
#     "Pre-existing hypertensive heart and renal disease complicating pregnancy, childbirth and the puerperium",
#     "Migraine variants, not intractable",
#     "Cardiorespiratory arrest",
#     "Calciphylaxis",
#     "Senile hemangioma of lip",
#     "Cerebral autosomal dominant arteriopathy with subcortical infarcts and leukoencephalopathy",
#     "Meningococcal pericarditis",
#     "Coxsackie endocarditis",
#     "Cardiac complications of anesthesia during labor and delivery",
#     "Cardiac arrest due to miscarriage",
#     "Pre-eclampsia added to pre-existing hypertension",
#     "Angiofibroma",
#     "Pericardial effusion",
#     "Pericardial effusion - noninflammatory",
#     "Central retinal vein occlusion",
#     "Venous retinal branch occlusion",
#     "Transient hypertension of pregnancy",
#     "Infective endocarditis",
#     "Cardiovascular system complication of procedure",
#     "Incomplete miscarriage with embolism",
#     "Hypotensive episode",
#     "Migraine variant with headache",
#     "Vascular lesions of cord with antenatal problem",
#     "Measles with complication",
#     "Angina, class I",
#     "Neoplasm of pericardium",
#     "Livedo reticularis",
#     "Injury of C5-C7 level with anterior cord syndrome",
#     "Tuberculosis of heart",
#     "Meningococcal carditis",
#     "Rubella with neurological complication",
#     "Chronic gastrojejunal ulcer with hemorrhage",
#     "Near syncope",
#     "Pigmented purpuric lichenoid dermatitis of Gougerot and Blum",
#     "Maternal hypotension syndrome",
#     "Cardiac transplant rejection",
#     "Cardiac insufficiency during AND/OR resulting from a procedure",
#     "Gastric ulcer with hemorrhage and perforation",
#     "Gastric hemorrhage due to alcoholic gastritis",
#     "Anterior spinal artery compression syndrome",
#     "Cardiovascular syphilis",
#     "Hemicrania continua",
#     "Migraine without aura, not refractory",
#     "Adhesive pericarditis",
#     "Rupture of chordae tendineae",
#     "Abnormality of aortic arch branch",
#     "Pre-existing secondary hypertension complicating pregnancy, childbirth and puerperium",
#     "Malignant secondary renovascular hypertension",
#     "HELLP syndrome",
#     "Triple vessel disease of the heart",
#     "Flushing",
#     "Refractory migraine with aura",
#     "Migraine variants",
#     "Pre-existing hypertension complicating pregnancy, childbirth and puerperium",
#     "Cerebrovascular accident",
#     "Retinal neovascularization",
#     "Hypertension complicating pregnancy, childbirth and the puerperium",
#     "Severe pre-eclampsia",
#     "Malignant hypertensive heart disease",
#     "Malignant hypertensive heart disease without congestive heart failure",
#     "Benign hypertensive heart disease with congestive cardiac failure",
#     "Hypertensive heart AND chronic kidney disease with congestive heart failure",
#     "Renal hypertension",
#     "Cardiovascular system hereditary disorder",
#     "Perinatal cardiovascular disorders",
#     "Drug-induced hypotension",
#     "Hemodialysis-associated hypotension",
#     "Vascular hamartomas",
#     "Venous malformation",
#     "Cerebral arteriovenous malformation",
#     "Pulmonary vein stenosis",
#     "Subclavian vein stenosis",
#     "Persistent hematuria co-occurrent and due to diffuse endocapillary proliferative glomerulonephritis",
#     "Rubella encephalomyelitis",
#     "Maternal rubella in the puerperium - baby delivered during current episode of care",
#     "Measles with intestinal complications",
#     "Ischemic toe",
#     "Gonococcal endocarditis",
#     "Neoplasm of uncertain behavior of blood vessel",
#     "Open fracture of C1-C4 level with anterior cord syndrome",
#     "Moderate proteinuric hypertension of pregnancy",
#     "Benign hypertension",
#     "Benign essential hypertension",
#     "Abnormality of systemic vein",
#     "Cerebrovascular disease",
#     "Vascular headache",
#     "Peripheral vascular disease",
#     "Migraine",
#     "Cerebrovascular disorder in the puerperium",
#     "Subsequent myocardial infarction of inferior wall",
#     "Subsequent myocardial infarction of anterior wall",
#     "Phlebitis of popliteal vein",
#     "Middle cerebral artery syndrome",
#     "Dilated blood vessels in skin",
#     "Mixed dementia",
#     "Basilar migraine",
#     "Malignant mesothelioma of pericardium",
#     "Intractable ophthalmic migraine",
#     "Histoplasmosis with pericarditis",
#     "Acquired coronary artery fistula",
#     "Malignant hypertension",
#     "Malignant essential hypertension",
#     "Pregnancy-induced hypertension",
#     "Refractory migraine",
#     "Migraine with aura",
#     "Central retinal artery occlusion",
#     "Arterial retinal branch occlusion",
#     "Prinzmetal angina",
#     "Angina decubitus",
#     "Cardiac tamponade",
#     "Mural thrombus of heart",
#     "Refractory migraine variants",
#     "Cerebellar stroke syndrome",
#     "Moyamoya disease",
#     "Atresia of pulmonary valve",
#     "Post cardiac operation functional disturbance",
#     "Mild pre-eclampsia"
#   ],
#   "chronic disease of cardiovascular system": [
#     "Chronic congestive heart failure",
#     "Systolic hypertension",
#     "Chronic combined systolic and diastolic heart failure",
#     "Non-rheumatic mitral valve disease",
#     "Benign hypertensive heart disease",
#     "Benign hypertensive heart disease without congestive heart failure",
#     "Hypertensive heart and renal disease with (congestive) heart failure",
#     "Hypertensive heart AND renal disease",
#     "Hypertensive left ventricular hypertrophy",
#     "Old inferior myocardial infarction",
#     "Right ventricular systolic dysfunction",
#     "Renal hypertension complicating pregnancy, childbirth and the puerperium - not delivered",
#     "Hypertension associated with transplantation",
#     "Chronic disease of cardiovascular system",
#     "Chronic heart disease",
#     "Chronic heart failure",
#     "Ischemic heart disease",
#     "Congestive heart failure",
#     "Heart failure",
#     "Hypertensive heart disease",
#     "Idiopathic pulmonary arterial hypertension",
#     "Hyperkinetic heart disease",
#     "Chronic adhesive pericarditis",
#     "Left atrial enlargement",
#     "Pre-existing hypertensive chronic kidney disease in mother complicating pregnancy",
#     "Heart failure with normal ejection fraction",
#     "Primary hypertrophic cardiomyopathy",
#     "Primary familial hypertrophic cardiomyopathy",
#     "Mitral valve annular calcification",
#     "Chronic rheumatic pericarditis",
#     "Ischemic congestive cardiomyopathy",
#     "Left ventricular systolic dysfunction",
#     "Left ventricular diastolic dysfunction",
#     "Stable angina",
#     "Restrictive cardiomyopathy with endomyocardial fibrosis",
#     "Right heart failure secondary to left heart failure",
#     "Essential hypertension in obstetric context",
#     "Chronic migraine without aura",
#     "Multi-infarct dementia with depression",
#     "Pre-existing hypertension complicating AND/OR reason for care during pregnancy",
#     "Atherosclerotic renal artery stenosis",
#     "Chronic right-sided heart failure",
#     "Chronic gastric ulcer with hemorrhage but without obstruction",
#     "Pre-existing hypertension complicating AND/OR reason for care during childbirth",
#     "Exertional hypotension",
#     "Postoperative hypertension",
#     "Myocardial degeneration",
#     "Rheumatic heart valve stenosis with insufficiency",
#     "Benign secondary renovascular hypertension",
#     "Severe pre-eclampsia - not delivered",
#     "Pre-eclampsia or eclampsia with pre-existing hypertension - delivered",
#     "Endomyocardial fibrosis",
#     "Takayasu's disease",
#     "Malignant secondary hypertension",
#     "Chronic peripheral venous hypertension",
#     "Pulmonary arterial hypertension",
#     "Secondary pulmonary hypertension",
#     "Benign essential hypertension complicating pregnancy, childbirth and the puerperium - delivered with postnatal complication",
#     "Chagas' disease with heart involvement",
#     "Transient hypertension",
#     "Chronic thromboembolic pulmonary hypertension",
#     "Congestive heart failure due to left ventricular systolic dysfunction",
#     "Intermittent hypertension",
#     "Congestive heart failure stage C",
#     "Cardiorenal syndrome",
#     "Senile cardiac amyloidosis",
#     "Primary restrictive cardiomyopathy",
#     "Chronic Chagas disease with heart involvement",
#     "High output heart failure",
#     "Primary dilated cardiomyopathy",
#     "Chronic mixed headache syndrome",
#     "Benign hypertensive heart AND renal disease",
#     "Silent myocardial ischemia",
#     "Multi vessel coronary artery disease",
#     "Chronic deep venous thrombosis of internal jugular vein",
#     "Chronic thrombosis of subclavian vein",
#     "Chronic pulmonary embolism",
#     "Chronic vascular insufficiency of intestine",
#     "Hypertensive heart and chronic kidney disease",
#     "Chronic peripheral venous hypertension with lower extremity complication",
#     "Non-proteinuric hypertension of pregnancy",
#     "Chronic systolic heart failure",
#     "Chronic diastolic heart failure",
#     "Chronic ischemic heart disease",
#     "Hypertensive heart disease without congestive heart failure",
#     "Hypertensive heart failure",
#     "Chronic passive congestion of liver",
#     "Chronic occlusion of artery of extremity",
#     "Chronic deep venous thrombosis of upper extremity",
#     "Chronic cor pulmonale",
#     "Hypertensive heart and renal disease with both (congestive) heart failure and renal failure",
#     "Nonischemic congestive cardiomyopathy",
#     "Secondary dilated cardiomyopathy",
#     "Secondary nonischemic congestive cardiomyopathy",
#     "Restrictive cardiomyopathy",
#     "Benign essential hypertension complicating pregnancy, childbirth and the puerperium - delivered",
#     "Chronic constrictive pericarditis",
#     "Biventricular congestive heart failure",
#     "Dilated cardiomyopathy secondary to peripartum heart disease",
#     "Chronic hypotension",
#     "Malignant hypertensive heart disease with congestive heart failure",
#     "Hypertensive heart and renal disease with renal failure",
#     "Benign secondary hypertension",
#     "Hypertensive heart disease with congestive heart failure",
#     "Hypertensive heart AND chronic kidney disease stage 5",
#     "Benign essential hypertension complicating pregnancy, childbirth and the puerperium - not delivered",
#     "Chronic pericarditis",
#     "Left ventricular hypertrophy",
#     "Congestive heart failure with right heart failure",
#     "Heart failure with reduced ejection fraction",
#     "Hypertensive nephrosclerosis",
#     "Chronic total occlusion of coronary artery",
#     "Chronic deep venous thrombosis",
#     "Chronic deep venous thrombosis of lower extremity",
#     "Chronic venous thrombosis",
#     "Multi-infarct dementia with delusions",
#     "Pre-existing hypertensive heart and chronic kidney disease in mother complicating childbirth",
#     "Low output heart failure"
#   ],
#   "congenital anomaly of cardiovascular structure of trunk": [
#     "Congenital anomaly of vena cava",
#     "Congenital anomaly of superior vena cava",
#     "Isomerism of atrial appendages",
#     "Ebstein's anomaly of common atrioventricular valve",
#     "Congenital anomaly of coronary artery",
#     "Congenital hypertrophy of cardiac ventricle",
#     "Anomalous cardiac muscle bands",
#     "Left ventricular outflow tract obstruction",
#     "Cor triatriatum",
#     "Abnormality of mitral valve annulus",
#     "Congenital cardiovascular disorder during pregnancy - baby delivered",
#     "Congenital abnormality of supraaortic branch of thoracic aorta",
#     "Right ventricular outflow tract obstruction",
#     "Interventricular cardiac septal hypertrophy",
#     "Congenital phlebectasia",
#     "Congenital hypoplasia of aorta",
#     "Congenital insufficiency of mitral valve",
#     "Congenital anomaly of tricuspid valve",
#     "Congenital stenosis of vena cava",
#     "Rupture of interventricular septum",
#     "Common ventricle",
#     "Bulbus cordis and cardiac septal closure anomalies",
#     "Aortopulmonary window",
#     "Congenital anomaly of aortic arch",
#     "Coarctation of aorta",
#     "Congenital anomaly of cardiovascular structure of trunk",
#     "Congenital atresia of aorta",
#     "Abnormality of aortic arch",
#     "Congenital stenosis of aorta",
#     "Ascending aorta abnormality",
#     "Congenital anomaly of aortic valve",
#     "Congenital stenosis of pulmonary valve",
#     "Congenital abnormality of cardiac connection"
#   ],
#   "congenital anomaly of cardiovascular system": [
#     "Hypoplasia of right heart",
#     "Right hypoplastic heart syndrome",
#     "Neonatal cardiac failure",
#     "Congenital hypoplasia of pulmonary artery",
#     "Congenital heart disease",
#     "Cardiac septal defects",
#     "Neonatal cyanosis",
#     "Congenital arteriovenous malformation",
#     "Myxoma of heart",
#     "Congenital dilatation of aorta",
#     "Coarctation of pulmonary artery",
#     "Congenital renal artery stenosis",
#     "Fetal cardiovascular disorder",
#     "Atrioventricular septal defect and common atrioventricular junction",
#     "Congenital atresia of pulmonary valve",
#     "Abnormality of fetal heart",
#     "Perinatal pneumopericardium",
#     "Ventricular septal defect",
#     "Ostium secundum type atrial septal defect",
#     "Congenital anomaly of aorta",
#     "Congenital abnormality of systemic artery",
#     "Fetal heart disorder",
#     "Eisenmenger's syndrome",
#     "Coronary artery fistula",
#     "Scimitar syndrome",
#     "Fetal pericardial effusion",
#     "Congenital stenosis of pulmonary veins",
#     "Congenital vascular anomaly of eye",
#     "Arterial tortuosity syndrome",
#     "Abnormality of common atrioventricular valve in atrioventricular septal defect",
#     "Discordant ventriculoarterial connection",
#     "Williams syndrome",
#     "Pulmonary stenosis, non-rheumatic",
#     "Congenital atresia of tricuspid valve",
#     "Total anomalous pulmonary venous return",
#     "Anomalous pulmonary venous drainage",
#     "Congenital abnormality of aortic valve cusp",
#     "Bicuspid cardiac valve",
#     "Abnormal number of cusps",
#     "Tricuspid valve stenosis with insufficiency",
#     "Atrial septal defect due to and following acute myocardial infarction",
#     "Pulmonary valve stenosis with insufficiency",
#     "Atrial septal defect",
#     "Congenital anomaly of heart valve",
#     "Congenital anomaly of pulmonary veins",
#     "Congenital stenosis of tricuspid valve",
#     "Congenital malposition of heart",
#     "Congenital insufficiency of pulmonary valve",
#     "Endocardial fibroelastosis",
#     "Congenital hypoplasia of heart",
#     "Hypoplastic left heart syndrome",
#     "Congenital anomaly of mitral valve",
#     "Congenital anomaly of pulmonary artery",
#     "Congenital anomaly of cardiovascular system",
#     "Endocardial cushion defect",
#     "Congenital stenosis of aortic valve",
#     "Dextrocardia",
#     "Congenital cardiovascular disorder during pregnancy - baby not yet delivered",
#     "Patent ductus arteriosus",
#     "Congenital stenosis of cardiac valve",
#     "Congenital septal defect of heart",
#     "Congenital insufficiency of aortic valve",
#     "Congenital pulmonary valve abnormality",
#     "Congenital conduction defect",
#     "Congenital heart block",
#     "Congenital stenosis of mitral valve",
#     "Partial anomalous pulmonary venous connection"
#   ],
#   "congenital vascular disorder": [
#     "Arteriovenous malformation of limb",
#     "Spinal arteriovenous malformation",
#     "Congenital vascular disorder",
#     "Congenital vascular malformation",
#     "Kartagener syndrome",
#     "Venous-lymphatic malformation",
#     "Congenital arteriovenous malformation",
#     "Juvenile myopathy, encephalopathy, lactic acidosis AND stroke",
#     "Arteriovenous malformation of precerebral vessels",
#     "Osler hemorrhagic telangiectasia syndrome",
#     "Alveolar capillary dysplasia with pulmonary venous misalignment",
#     "Congenital vascular nevus",
#     "Popliteal entrapment syndrome",
#     "Congenital phlebectasia",
#     "Congenital atresia of pulmonary artery",
#     "Vascular anomaly of umbilical cord",
#     "Velamentous insertion of umbilical cord",
#     "Congenital stenosis of pulmonary veins",
#     "Congenital arteriovenous malformation of gastrointestinal tract",
#     "Congenital anomaly of renal blood vessel",
#     "Congenital anomaly of blood vessel of upper limb",
#     "Pulmonary arteriovenous malformation",
#     "Arteriovenous fistula of pulmonary vessels",
#     "Anomalies of great veins",
#     "Congenital anomaly of cerebrovascular system",
#     "Congenital anomaly of peripheral blood vessel",
#     "Congenital abnormality of vein",
#     "Congenital valvular insufficiency",
#     "Dieulafoy's vascular malformation",
#     "Angiokeratoma of skin"
#   ],
#   "thrombosis": [
#     "Thrombotic microangiopathy",
#     "Thrombus of cardiac chamber",
#     "Thrombosis of subclavian vein",
#     "Thrombosis of vena cava",
#     "Acute thrombosis of subclavian vein",
#     "Thrombosis of arteries of upper extremity",
#     "Cerebral thrombosis",
#     "Thrombotic stroke",
#     "Intracranial venous thrombosis",
#     "Cerebral venous sinus thrombosis",
#     "Nonpyogenic thrombosis of intracranial venous sinus",
#     "Vertebral artery thrombosis",
#     "Deep venous thrombosis of profunda femoris vein",
#     "Thromboembolism of vein",
#     "Thrombosis of thoracic aorta",
#     "Pulmonary thrombosis",
#     "Thrombosis of arteries of lower extremity",
#     "Thrombosis of pelvic vein",
#     "Thrombosis of cavernous venous sinus",
#     "Arteriovenous graft thrombosis",
#     "Antenatal deep vein thrombosis - delivered",
#     "Superficial thrombophlebitis in puerperium",
#     "Superficial thrombophlebitis in pregnancy",
#     "Coronary artery thrombosis",
#     "Coronary thrombosis not resulting in myocardial infarction",
#     "Thrombosis of renal vein",
#     "Celiac artery thrombosis",
#     "Arterial thrombosis",
#     "Deep venous thrombosis",
#     "Thrombosis of vein of lower limb",
#     "Deep venous thrombosis of lower extremity",
#     "Acute deep venous thrombosis",
#     "Acute deep vein thrombosis of lower limb",
#     "Thrombosis of the popliteal vein",
#     "Acute thrombosis of superficial vein of upper extremity",
#     "Thrombophlebitis migrans",
#     "Postpartum deep phlebothrombosis",
#     "Thrombosis of penis",
#     "Thrombosis of cerebral veins",
#     "Thrombosis of internal jugular vein",
#     "Superior mesenteric vein thrombosis",
#     "Thrombosis of superior vena cava",
#     "Atrial thrombosis",
#     "Thrombophlebitis of deep veins of upper extremities",
#     "Thromboangiitis",
#     "Thromboangiitis obliterans",
#     "Basilar artery thrombosis",
#     "Thrombosis of superficial vein of lower limb",
#     "Thrombosis of inferior vena cava",
#     "Saphenous vein thrombophlebitis",
#     "Thrombophlebitis of pelvic vein",
#     "Splenic vein thrombosis",
#     "Phlebitis of iliac vein",
#     "Thrombophlebitis",
#     "Thrombosis of penile vein",
#     "Thrombosis of superficial vein of penis",
#     "Vascular graft thrombosis",
#     "Cerebral venous thrombosis in the puerperium",
#     "Cerebral venous thrombosis in pregnancy",
#     "Postpartum thrombophlebitis",
#     "Occlusion and stenosis of multiple and bilateral cerebral arteries",
#     "Occlusion and stenosis of anterior cerebral artery",
#     "Thrombosis",
#     "Thrombosis of blood vessel",
#     "Venous thrombosis",
#     "Thrombophlebitis of breast",
#     "Phlebolithiasis",
#     "Prosthetic cardiac valve thrombosis",
#     "Deep venous thrombosis of peroneal vein",
#     "Thrombophlebitis of superficial veins of lower leg",
#     "Septic thrombophlebitis",
#     "Chronic thrombosis of superficial vein of upper extremity",
#     "Suppurative phlebitis",
#     "Deep venous thrombosis of pelvic vein",
#     "Recurrent deep vein thrombosis"
#   ],
#   "thrombosis of blood vessel": [
#     "Thrombosis of iliac artery",
#     "Thrombosis of abdominal aorta",
#     "Embolism and thrombosis of the abdominal aorta",
#     "Thrombophlebitis of superficial veins of upper extremities",
#     "Deep venous thrombosis of tibial vein",
#     "Acute deep venous thrombosis of axillary vein",
#     "Axillary vein thrombosis",
#     "Embolism and thrombosis of the thoracic aorta",
#     "Carotid artery thrombosis",
#     "Deep venous thrombosis of upper extremity",
#     "Acute deep venous thrombosis of upper extremity",
#     "Superficial vein thrombosis",
#     "Popliteal artery occlusion",
#     "Basilar artery occlusion",
#     "Occlusion and stenosis of middle cerebral artery",
#     "Partial retinal artery occlusion",
#     "Cerebral venous thrombosis of cortical vein",
#     "Thrombophlebitis of lower extremities",
#     "Portal vein thrombosis",
#     "Occlusion and stenosis of posterior cerebral artery",
#     "Dissection of iliac artery",
#     "Thrombosis of retinal vein",
#     "Thrombosis of vein of upper limb",
#     "Thrombosis of vein of trunk",
#     "Thrombosis of arteries of the extremities",
#     "Thrombosis of cerebral veins",
#     "Thrombosis of internal jugular vein",
#     "Superior mesenteric vein thrombosis",
#     "Thrombosis of superior vena cava",
#     "Thrombosis of mesenteric vein",
#     "Antepartum deep vein thrombosis",
#     "Basilar artery thrombosis",
#     "Branch retinal vein occlusion with macular edema",
#     "Ischemic hand",
#     "Ischemic foot",
#     "Occlusion of arterial bypass graft",
#     "Occlusion of cerebral artery with stroke",
#     "Ischemic stroke",
#     "Middle cerebral artery syndrome",
#     "Transient ischemia",
#     "Diffuse cerebrovascular disease",
#     "Superficial thrombophlebitis",
#     "Phlebitis of deep femoral vein",
#     "Thrombosis of retinal artery",
#     "Thrombosis transverse sinus",
#     "Postoperative deep vein thrombosis",
#     "Thrombotic thrombocytopenic purpura",
#     "Right carotid artery occlusion",
#     "Left carotid artery occlusion",
#     "Cerebellar artery occlusion",
#     "Occlusion and stenosis of cerebellar arteries",
#     "Postpartum septic thrombophlebitis"
#   ],
#   "vascular disease of abdomen": [
#     "Dissection of abdominal aorta",
#     "Atherosclerosis of renal artery",
#     "Varicocele",
#     "Gastric varices",
#     "Celiac artery compression syndrome",
#     "Budd-Chiari syndrome",
#     "Dissection of renal artery",
#     "Traumatic injury of celiac artery",
#     "Subclavian artery stenosis",
#     "Chronic vascular insufficiency of intestine",
#     "Focal segmental ischemia of small intestine",
#     "Vascular insufficiency of intestine",
#     "Portal hypertension",
#     "Esophageal varices",
#     "Superior mesenteric vein thrombosis",
#     "Injury of inferior mesenteric vein",
#     "Abdominal angina",
#     "Mesenteric artery stenosis",
#     "Acute gastric ulcer with hemorrhage and perforation",
#     "Acute gastrojejunal ulcer with hemorrhage",
#     "Chronic gastric ulcer with hemorrhage and with perforation",
#     "Gastric ulcer with hemorrhage AND perforation but without obstruction",
#     "Angiodysplasia of small intestine",
#     "Angiodysplasia of duodenum",
#     "Angiodysplasia of stomach",
#     "Leriche's syndrome",
#     "Renal infarction",
#     "Hepatic infarction",
#     "Phlebitis of portal vein",
#     "Vascular disease of abdomen",
#     "Stenosis of abdominal aorta",
#     "Dissection of proximal aorta",
#     "Dissection of distal aorta",
#     "Angiodysplasia of intestine",
#     "Vascular ectasia of colon",
#     "Veno-occlusive disease of the liver",
#     "Acquired arteriovenous fistula of liver",
#     "Portal pyemia",
#     "Abnormality of abdominal aorta",
#     "Dilatation of descending aorta",
#     "Abdominal aortic ectasia",
#     "Arteriosclerosis of aorta",
#     "Atherosclerosis of aorta",
#     "Aortoiliac atherosclerosis",
#     "Terminal aortic occlusion"
#   ],
#   "embolism": [
#     "Complete miscarriage with embolism",
#     "Failed attempted termination of pregnancy complicated by embolism",
#     "Illegal termination of pregnancy complicated by embolism",
#     "Air embolism in childbirth",
#     "Venous embolism",
#     "Thromboembolism of vein",
#     "Retinal embolus",
#     "Air embolism as early complication of trauma",
#     "Fat embolism as early complication of trauma",
#     "Pulmonary air embolism",
#     "Obstetric air pulmonary embolism",
#     "Miscarriage complicated by embolism",
#     "Embolism of vena cava",
#     "Embolism and thrombosis of the vena cava",
#     "Embolism of iliac artery",
#     "Pulmonary embolism with pulmonary infarction",
#     "Embolism from thrombosis of vein of lower extremity",
#     "Saddle embolus of pulmonary artery",
#     "Septic pulmonary embolism",
#     "Basilar artery embolism",
#     "Arterial embolus and thrombosis",
#     "Acute pulmonary embolism",
#     "Cerebral venous thrombosis of cortical vein",
#     "Chronic pulmonary embolism",
#     "Arterial embolism",
#     "Pulmonary embolism",
#     "Renal artery embolism",
#     "Septic embolus of artery",
#     "Amniotic fluid pulmonary embolism - delivered",
#     "Amniotic fluid pulmonary embolism with antenatal complication",
#     "Obstetric pyemic and septic pulmonary embolism",
#     "Induced termination of pregnancy complicated by embolism",
#     "Cholesterol embolus syndrome",
#     "Embolism of renal vein",
#     "Embolism and thrombosis of the renal vein",
#     "Air embolism",
#     "Obstetric blood-clot pulmonary embolism",
#     "Amniotic fluid embolism in childbirth",
#     "Pyemic and septic embolism in pregnancy",
#     "Legal termination of pregnancy complicated by embolism",
#     "Amniotic fluid pulmonary embolism with postnatal complication",
#     "Vertebral artery embolism",
#     "Amniotic fluid embolism",
#     "Thromboembolic disorder",
#     "Cerebral embolism",
#     "Embolism from thrombosis of vein of distal lower extremity",
#     "Cholesterol retinal embolus",
#     "Fat embolism",
#     "Air embolism as a complication of medical care",
#     "Upper limb arterial embolus",
#     "Lower limb arterial embolus",
#     "Carotid artery embolism",
#     "Obstetric pulmonary embolism",
#     "Pyemic and septic embolism in childbirth",
#     "Pulmonary fat embolism",
#     "Embolism"
#   ],
#   "heart valve disorder": [
#     "Tricuspid valve prolapse",
#     "Rheumatic heart valve failure",
#     "Prosthetic valve endocarditis",
#     "Rheumatic disease of mitral valve",
#     "Mitral and aortic incompetence",
#     "Cardiac valve prolapse",
#     "Mitral valve prolapse",
#     "Rheumatic heart valve regurgitation",
#     "Pulmonic valve stenosis",
#     "Disorders of both mitral and tricuspid valves",
#     "Rheumatic disease of tricuspid valve",
#     "Rheumatic disease of aortic valve",
#     "Rheumatic tricuspid valve regurgitation",
#     "Syphilis of mitral valve",
#     "Infective endocarditis of mitral valve",
#     "Heart valve disorder",
#     "Mitral valve disorder",
#     "Aortic valve disorder",
#     "Non-rheumatic heart valve disorder",
#     "Aortic stenosis, non-rheumatic",
#     "Rheumatic aortic stenosis with regurgitation",
#     "Rheumatic mitral stenosis with regurgitation",
#     "Abnormality of atrioventricular (non-mitral, non-tricuspid) valve",
#     "Aortic valve cusp abnormality",
#     "Mitral valve regurgitation",
#     "Mitral valve stenosis",
#     "Mitral stenosis with insufficiency",
#     "Non-rheumatic mitral valve stenosis",
#     "Non-rheumatic mitral regurgitation",
#     "Non-rheumatic mitral valve stenosis with regurgitation",
#     "Heart valve stenosis and regurgitation",
#     "Tricuspid valve disorder, non-rheumatic",
#     "Tricuspid valve stenosis",
#     "Rheumatic mitral stenosis",
#     "Rheumatic aortic stenosis",
#     "Mitral and aortic stenosis",
#     "Non-rheumatic tricuspid valve stenosis with insufficiency",
#     "Prosthetic cardiac paravalvular leak",
#     "Infective endocarditis of aortic valve",
#     "Candidal endocarditis",
#     "Mycotic endocarditis",
#     "Tricuspid valve regurgitation",
#     "Aortic incompetence, non-rheumatic",
#     "Tricuspid incompetence, non-rheumatic",
#     "Aortic valve stenosis",
#     "Abnormality of pulmonary valve",
#     "Rheumatic heart valve stenosis",
#     "Rheumatic disease of mitral AND aortic valves",
#     "Disorders of both aortic and tricuspid valves",
#     "Pulmonic valve regurgitation",
#     "Heart valve regurgitation",
#     "Tricuspid valve disorder",
#     "Heart valve stenosis",
#     "Abnormality of aortic valve",
#     "Rheumatic disease of pulmonary valve",
#     "Mitral insufficiency and aortic stenosis",
#     "Combined disorders of mitral, aortic and tricuspid valves",
#     "Rheumatic mitral regurgitation",
#     "Aortic valve stenosis with insufficiency",
#     "Pulmonary incompetence, non-rheumatic",
#     "Non-rheumatic aortic valve stenosis with regurgitation",
#     "Prosthetic cardiac valve displacement",
#     "Valvular cardiomyopathy",
#     "Rheumatic heart valve stenosis with insufficiency",
#     "Aortic valve calcification",
#     "Aortic valve sclerosis",
#     "Mechanical complication of heart valve prosthesis",
#     "Critical stenosis of aortic valve",
#     "Syphilitic endocarditis",
#     "Infectious pericarditis",
#     "Mechanical breakdown of prosthetic heart valve",
#     "Rheumatic tricuspid stenosis and insufficiency",
#     "Mitral leaflet abnormality",
#     "Non-rheumatic pulmonary valve stenosis with regurgitation",
#     "Valvular sclerosis",
#     "Non-rheumatic aortic sclerosis",
#     "Aortic valve regurgitation",
#     "Rheumatic heart disease",
#     "Multiple valve disease",
#     "Rheumatic disease of heart valve",
#     "Diseases of mitral and aortic valves",
#     "Pulmonary valve disorder",
#     "Aortic cusp regurgitation",
#     "Rheumatic aortic regurgitation",
#     "Tricuspid stenosis, non-rheumatic",
#     "Tricuspid leaflet abnormality",
#     "Mitral valve annular calcification",
#     "Rheumatic tricuspid valve stenosis",
#     "Mitral stenosis and aortic insufficiency",
#     "Mechanical complication due to heart valve prosthesis",
#     "Mitral valve vegetations",
#     "Aortic valve vegetations",
#     "Prosthetic cardiac valve thrombosis"
#   ],
#   "acute disease of cardiovascular system": [
#     "Cardioembolic stroke",
#     "Cerebellar stroke",
#     "Sudden cardiac death",
#     "Coxsackie myocarditis",
#     "Listerial endocarditis",
#     "Coxsackie pericarditis",
#     "Acute coronary syndrome",
#     "Non-Q wave myocardial infarction",
#     "Rapid atrial fibrillation",
#     "Acute right-sided heart failure",
#     "Acute congestive heart failure",
#     "Cardiac arrest during surgery",
#     "Severe pre-eclampsia - delivered with postnatal complication",
#     "Acute gastric ulcer with hemorrhage and obstruction",
#     "Acute disease of cardiovascular system",
#     "Acute heart disease",
#     "Acute ischemic heart disease",
#     "Myocardial infarction",
#     "Angina pectoris",
#     "Acute anteroseptal myocardial infarction",
#     "Acute myocardial infarction of atrium",
#     "Low cardiac output syndrome",
#     "Acute deep venous thrombosis of pelvic vein",
#     "Acute rheumatic pericarditis",
#     "Viral myocarditis",
#     "Isolated (Fiedler's) myocarditis",
#     "Acute myocardial ischemia",
#     "Transient myocardial ischemia of newborn",
#     "Bacterial pericarditis",
#     "Acute non-Q wave infarction",
#     "Acute anterior ST segment elevation myocardial infarction",
#     "Silent myocardial infarction",
#     "Exercise-induced angina",
#     "Acute myocarditis associated with another disorder",
#     "Cardiac arrest in fetus OR newborn",
#     "Neonatal cardiac arrest",
#     "Exacerbation of congestive heart failure",
#     "Accelerated coronary artery disease in transplanted heart",
#     "Acute myocardial infarction",
#     "Acute heart failure",
#     "Acute systolic heart failure",
#     "Acute diastolic heart failure",
#     "Hypertensive crisis",
#     "Acute pericarditis",
#     "Acute cerebrovascular insufficiency",
#     "Acute cor pulmonale",
#     "Acute myocardial infarction of anterolateral wall",
#     "Acute infective endocarditis",
#     "Acute bacterial endocarditis",
#     "Acute bowel infarction",
#     "Acute rheumatic heart disease",
#     "Subsequent non-ST segment elevation myocardial infarction",
#     "Saddle embolus of pulmonary artery with acute cor pulmonale",
#     "Acute non-ST segment elevation myocardial infarction",
#     "Acute combined systolic and diastolic heart failure",
#     "Acute rheumatic myocarditis",
#     "Viral pericarditis",
#     "Cardiac arrest with successful resuscitation",
#     "Acute rheumatic endocarditis",
#     "Idiopathic myocarditis",
#     "Acute and subacute infective endocarditis associated with another disorder",
#     "Acute gastric ulcer with hemorrhage",
#     "Acute hemorrhagic gastritis",
#     "Pre-eclampsia or eclampsia with pre-existing hypertension",
#     "CLABSI - central line associated bloodstream infection",
#     "Hypertensive emergency",
#     "Acute on chronic systolic heart failure",
#     "Acute on chronic diastolic heart failure",
#     "Acute subendocardial infarction",
#     "Subendocardial ischemia",
# ...
#     "Acute on chronic combined systolic and diastolic heart failure",
#     "Pre-eclampsia",
#     "Acute myocardial infarction of inferoposterior wall",
#     "Acute myocardial infarction of lateral wall",
#     "Cardiac arrest due to cardiac disorder",
#     "Acute myocarditis",
#     "Acute idiopathic pericarditis",
#     "Subclavian steal syndrome",
#     "Subaortic stenosis",
#     "Acute ST segment elevation myocardial infarction involving left anterior descending coronary artery",
#     "Acute coronary artery occlusion not resulting in myocardial infarction",
#     "Acute myocardial infarction due to right coronary artery occlusion",
#     "Acute ST segment elevation myocardial infarction due to right coronary artery occlusion",
#     "Acute myocardial infarction of inferolateral wall",
#     "Thunderclap headache",
#     "Primary thunderclap headache",
#     "Subsequent ST segment elevation myocardial infarction",
#     "Severe pre-eclampsia with postnatal complication",
#     "Acute myocardial infarction of inferior wall",
#     "Cardiogenic shock",
#     "Hypertensive urgency",
#     "Carditis due to rheumatic fever",
#     "Toxic myocarditis",
#     "Recurrent pulmonary embolism",
#     "Asystole",
#     "Progressive angina",
#     "Acute myocardial infarction of anterior wall",
#     "Acute endocarditis",
#     "Acute vascular insufficiency of intestine",
#     "True posterior myocardial infarction",
#     "Thrombosis of atrium, auricular appendage, and ventricle due to and following acute myocardial infarction",
#     "Carotid territory transient ischemic attack",
#     "Vertebrobasilar territory transient ischemic attack",
#     "Basilar artery syndrome",
#     "Rupture of aorta",
#     "Acute deep venous thrombosis of internal jugular vein",
#     "Severe pre-eclampsia - delivered",
#     "Bleeding esophageal varices",
#     "Acute ST segment elevation myocardial infarction of inferior wall",
#     "Cardiac complication of anesthesia during the puerperium",
#     "Meningococcal myocarditis",
#     "Myocarditis due to scarlet fever",
#     "Post-pericardiotomy syndrome"
#   ],
#   "aneurysm": [
#     "Aneurysm of femoral artery",
#     "Common iliac aneurysm",
#     "False aneurysm of artery",
#     "Syphilitic aneurysm of aorta",
#     "Aneurysm of popliteal artery",
#     "Congenital dilatation of aorta",
#     "Mycotic aneurysm",
#     "Vertebral artery aneurysm",
#     "Atrial septal aneurysm",
#     "Femoral false aneurysm",
#     "Aneurysm of subclavian artery",
#     "Aneurysm",
#     "Arterial aneurysm",
#     "Aortic aneurysm",
#     "Aneurysm of artery of lower extremity",
#     "Aneurysm of iliac artery",
#     "Aneurysm of splenic artery",
#     "Aneurysm of artery of upper extremity",
#     "Carotid artery aneurysm",
#     "Aneurysm of artery of neck",
#     "Aneurysm of thoracic aorta",
#     "Congenital arterial aneurysm",
#     "Pulmonary artery aneurysm",
#     "Intracranial aneurysm",
#     "Aneurysm of heart",
#     "Aneurysm of descending aorta",
#     "Left ventricular aneurysm",
#     "Atrial aneurysm",
#     "Aneurysm of coronary vessels",
#     "Aneurysm of renal artery",
#     "Aneurysm of artery, other than aorta",
#     "Pseudoaneurysm",
#     "Ventricular aneurysm",
#     "Dissection of aorta",
#     "Aneurysm of head and neck artery",
#     "Ruptured aneurysm of artery",
#     "Aneurysm of visceral artery"
#   ],
#   "cardiac arrhythmia": [
#     "Ventricular tachycardia, polymorphic",
#     "Ectopic atrial beats",
#     "Brugada syndrome",
#     "AV junctional rhythm",
#     "Rapid atrial fibrillation",
#     "Atrial fibrillation with rapid ventricular response",
#     "Wolff-Parkinson-White pattern",
#     "Tachycardia-bradycardia",
#     "Paroxysmal atrial flutter",
#     "Cardiac arrhythmia",
#     "Supraventricular arrhythmia",
#     "Atrial arrhythmia",
#     "Fibrillation",
#     "Atrial fibrillation",
#     "Re-entrant atrioventricular node tachycardia",
#     "Nonsustained paroxysmal ventricular tachycardia",
#     "Ventricular pre-excitation",
#     "Fetal bradycardia",
#     "Postural orthostatic tachycardia syndrome",
#     "AV nodal re-entry tachycardia",
#     "Fetal dysrhythmia",
#     "Torsades de pointes",
#     "Lone atrial fibrillation",
#     "Congenital long QT syndrome",
#     "Lown-Ganong-Levine syndrome",
#     "Junctional escape beats",
#     "AV node arrhythmia",
#     "Diffuse intraventricular block",
#     "Paroxysmal atrial fibrillation",
#     "Chronic atrial fibrillation",
#     "Tachyarrhythmia",
#     "Atrial flutter",
#     "Heart block",
#     "Sinus node dysfunction",
#     "Typical atrial flutter",
#     "Bradyarrhythmia",
#     "Bifascicular block",
#     "Neonatal bradycardia",
#     "Paroxysmal ventricular tachycardia",
#     "Aberrant premature complexes",
#     "Sick sinus syndrome",
#     "Paroxysmal supraventricular tachycardia",
#     "Persistent atrial fibrillation",
#     "Ventricular premature complex",
#     "Idioventricular rhythm",
#     "Nodal rhythm disorder",
#     "Ventricular bigeminy",
#     "Ectopic rhythm",
#     "Premature atrial contraction",
#     "Re-entry ventricular arrhythmia",
#     "Nonsustained ventricular tachycardia",
#     "Atrial paroxysmal tachycardia",
#     "Junctional premature complex",
#     "Atypical atrial flutter",
#     "Anomalous atrioventricular excitation",
#     "Paroxysmal tachycardia",
#     "Ventricular tachycardia",
#     "Supraventricular tachycardia",
#     "Premature beats",
#     "Atrioventricular conduction disorder",
#     "Atrioventricular block",
#     "Sustained ventricular tachycardia",
#     "Ectopic atrial tachycardia",
#     "Symptomatic sinus bradycardia",
#     "AV-junctional (nodal) bradycardia",
#     "Persistent sinus bradycardia",
#     "Ventricular fibrillation and flutter",
#     "AV junctional (nodal) tachycardia",
#     "Inappropriate sinus tachycardia",
#     "First degree atrioventricular block",
#     "Neonatal tachycardia",
#     "Sinus bradycardia",
#     "Ventricular flutter",
#     "Atrial fibrillation and flutter",
#     "Ventricular premature beats",
#     "Atrial tachycardia",
#     "Permanent atrial fibrillation",
#     "Ectopic beats",
#     "Supraventricular premature beats",
#     "Second degree atrioventricular block",
#     "Ventricular arrhythmia",
#     "Ventricular fibrillation",
#     "Multifocal atrial tachycardia",
#     "Atrial premature complex",
#     "Long QT syndrome",
#     "Accelerated atrioventricular conduction",
#     "Arrhythmogenic right ventricular dysplasia",
#     "Sinoatrial block"
#   ],
#   "cardiovascular injury": [
#     "Contusion to heart with open wound into thorax",
#     "Injury to heart and lung",
#     "Heart injury, closed",
#     "Laceration of heart with penetration of heart chambers",
#     "Injury of heart without open wound into thorax",
#     "Injury of iliac artery",
#     "Injury of vertebral artery",
#     "Injury of ulnar artery",
#     "Injury of superficial femoral artery",
#     "Axillary blood vessel injury",
#     "Injury of multiple blood vessels of upper extremity",
#     "Injury of innominate artery",
#     "Injury of multiple blood vessels at ankle and foot level",
#     "Cardiac transplant failure",
#     "Injury of heart with open wound into thorax",
#     "Major laceration of heart with hemopericardium",
#     "Renal blood vessel injury",
#     "Injury of radial artery",
#     "Injury of renal vessels",
#     "Traumatic injury of mesenteric artery",
#     "Injury of multiple blood vessels at forearm level",
#     "Injury of multiple blood vessels at lower leg level",
#     "Injury of multiple blood vessels at neck level",
#     "Injury of blood vessel",
#     "Injury of subclavian artery",
#     "Contusion to heart",
#     "Rupture of heart",
#     "Cardiac complication of procedure",
#     "Cardiac arrest",
#     "Heart injury, open",
#     "Laceration of heart",
#     "Injury of popliteal artery",
#     "Iliac blood vessel injury",
#     "Injury of common femoral artery",
#     "Injury to blood vessel of neck",
#     "Injury of artery",
#     "Moderate laceration of heart with hemopericardium",
#     "Heart laceration with open wound into thorax, with penetration of heart chambers",
#     "Rupture of cardiac wall without hemopericardium as current complication following acute myocardial infarction",
#     "Injury of heart with hemopericardium",
#     "Injury of heart",
#     "Mechanical complication of arteriovenous surgical fistula",
#     "Injury of radial blood vessel",
#     "Injury of carotid artery",
#     "Injury of thoracic aorta",
#     "Injury of popliteal vessels",
#     "Injury of vein of trunk",
#     "Ulnar blood vessel injury",
#     "Digital blood vessel injury",
#     "Dissection of artery",
#     "Heart transplant failure and rejection",
#     "Cardiovascular injury",
#     "Postoperative cardiac complication",
#     "Injury of aorta",
#     "Injury of systemic artery",
#     "Injury of branch of celiac axis",
#     "Injury of internal iliac vein",
#     "Injury of ovarian artery",
#     "Injury of uterine vein"
#   ],
#   "injury of blood vessel": [
#     "Compression of vein",
#     "Injury of external carotid artery",
#     "Injury of vein at forearm level",
#     "Injury of peroneal artery",
#     "Injury of intercostal artery",
#     "Injury of superior mesenteric vein AND/OR primary subdivisions",
#     "Injury of gastric artery",
#     "Injury of pulmonary artery",
#     "Injury of dorsalis pedis artery",
#     "Coronary artery spasm",
#     "Injury of blood vessels of thorax",
#     "Injury of femoral artery",
#     "Major laceration of external jugular vein",
#     "Carotid artery rupture",
#     "Injury of iliac vein",
#     "Injury of renal artery",
#     "Injury of posterior tibial artery",
#     "Injury of vein of upper limb",
#     "Injury of saphenous vein",
#     "Injury of radial artery at wrist and hand level",
#     "Injury of ulnar artery at wrist and hand level",
#     "Injury of blood vessel",
#     "Injury of brachial artery",
#     "Portal system vein injury",
#     "Injury of tibial blood vessel",
#     "Injury of femoral vein",
#     "Injury of internal carotid artery",
#     "Injury of inferior vena cava",
#     "Injury of abdominal aorta",
#     "Injury of axillary artery",
#     "Injury of multiple blood vessels of head AND/OR neck",
#     "Injury of celiac AND/OR mesenteric arteries",
#     "Dissection of cervicocerebral artery",
#     "Dissection of precerebral artery",
#     "Injury of axillary vein",
#     "Injury of pulmonary vein",
#     "Injury of deep plantar blood vessel",
#     "Injury of brachial vein",
#     "Injury of hepatic vein",
#     "Injury of dorsal vein of foot",
#     "Injury of inferior mesenteric vein",
#     "Minor laceration of carotid artery",
#     "Injury of posterior tibial vein",
#     "Injury of primary branch of superior mesenteric artery",
#     "Minor laceration of vertebral artery",
#     "Injury of hypogastric artery",
#     "Injury of blood vessels of head AND/OR neck",
#     "Injury of artery of lower limb",
#     "Injury of blood vessels of abdomen AND/OR pelvis",
#     "Injury of systemic artery of trunk",
#     "Arterial laceration",
#     "Injury of superficial palmar arch",
#     "Injury of blood vessels at ankle and foot level",
#     "Injury of splenic artery",
#     "Injury of common carotid artery",
#     "Injury of deep palmar arch",
#     "Injury of splenic vein",
#     "Injury of renal vein",
#     "Superior mesenteric vein injury",
#     "Injury of palmar artery",
#     "Injury of uterine artery",
#     "Injury of portal vein",
#     "Injury of hepatic artery",
#     "Greater saphenous vein injury",
#     "Injury of blood vessels of upper extremity",
#     "Injury to blood vessels of lower limb",
#     "Minor laceration of external jugular vein",
#     "Major laceration of carotid artery",
#     "Major laceration of vertebral artery",
#     "Major laceration of internal jugular vein",
#     "Minor laceration of internal jugular vein",
#     "Injury of multiple blood vessels of thorax",
#     "Injury of anterior tibial vein",
#     "Injury of ovarian vein",
#     "Injury of popliteal artery",
#     "Iliac blood vessel injury",
#     "Injury of common femoral artery",
#     "Injury to blood vessel of neck",
#     "Injury of subclavian artery",
#     "Injury of multiple blood vessels of abdomen AND/OR pelvis",
#     "Injury of inferior mesenteric artery",
#     "Injury of superficial vein at shoulder and upper arm level",
#     "Venous laceration",
#     "Injury of vein",
#     "Injury of anterior tibial artery",
#     "Injury of internal jugular vein",
#     "Injury of popliteal vein",
#     "Injury of blood vessels at forearm level",
#     "Injury of blood vessel(s) of thumb",
#     "Injury of superior mesenteric artery",
#     "Injury of superior vena cava",
#     "Injury of external jugular vein",
#     "Rupture iliac artery"
#   ],
#   "myocardial disease": [
#     "Dilated cardiomyopathy secondary to alcohol",
#     "Myocardial ischemia",
#     "Familial cardiomyopathy",
#     "Hypertrophic cardiomyopathy without obstruction",
#     "Myocardial bridge of coronary artery",
#     "Right ventricular failure",
#     "Right ventricular hypertrophy",
#     "Ventricular hypertrophy",
#     "Cor pulmonale",
#     "Postpartum cardiomyopathy",
#     "Hypertrophic cardiomyopathy",
#     "Right ventricular abnormality",
#     "Histoplasma duboisii with pericarditis",
#     "Gonococcal pericarditis",
#     "Syphilitic pericarditis",
#     "Myocardial degeneration",
#     "Acute myocarditis",
#     "Hypertrophic cardiomegaly",
#     "Primary idiopathic hypertrophic cardiomyopathy",
#     "Myocardial dysfunction",
#     "Ischemic myocardial dysfunction",
#     "Generalized ischemic myocardial dysfunction",
#     "Diphtheritic myocarditis",
#     "Primary cardiomyopathy",
#     "Cardiomegaly",
#     "Hypertrophic obstructive cardiomyopathy",
#     "Sarcoid heart muscle disease",
#     "Myocarditis due to infectious agent",
#     "Cardiac sarcoidosis",
#     "Primary dilated cardiomyopathy",
#     "Ischemia",
#     "Left ventricular abnormality",
#     "Dilated cardiomyopathy",
#     "Cardiomyopathy associated with another disorder",
#     "Primary idiopathic dilated cardiomyopathy",
#     "Dilated cardiomyopathy secondary to drug",
#     "Toxoplasma myocarditis",
#     "Subsequent myocardial infarction",
#     "Idiopathic myocarditis",
#     "Myocarditis",
#     "Takotsubo cardiomyopathy",
#     "Tachycardia-induced cardiomyopathy",
#     "Cardiomyopathy due to viral infection",
#     "Endomyocardial disease",
#     "Myocardial disease",
#     "Cardiomyopathy",
#     "Systolic heart failure",
#     "Diastolic heart failure",
#     "Mumps myocarditis",
#     "Bacterial myocarditis",
#     "Atrial dilatation",
#     "Viral carditis",
#     "Coxsackie myocarditis"
#   ],
#   "hemorrhage of blood vessel": [
#     "Arterial hemorrhage",
#     "Esophageal varices associated with another disorder",
#     "Gastric ulcer with hemorrhage",
#     "Acute gastric ulcer with hemorrhage but without obstruction",
#     "Fetal blood loss from ruptured cord",
#     "Subarachnoid hemorrhage from carotid siphon and bifurcation",
#     "Subgaleal hemorrhage",
#     "Gastric hemorrhage",
#     "Hemopericardium due to and following acute myocardial infarction",
#     "Rupture of papillary muscle",
#     "Vascular graft hemorrhage",
#     "Chronic gastric ulcer with hemorrhage",
#     "Gastric ulcer with hemorrhage but without obstruction",
#     "Renal artery hemorrhage",
#     "Massive subgaleal hemorrhage due to birth trauma",
#     "Venous hemorrhage",
#     "Rupture of artery",
#     "Choroidal hemorrhage and rupture",
#     "Injury of heart with hemopericardium",
#     "Gastric hemorrhage due to hypertrophic gastritis",
#     "Amaurosis fugax",
#     "Massive umbilical hemorrhage of newborn",
#     "Umbilical hemorrhage",
#     "Hemorrhage of blood vessel",
#     "Gastric hemorrhage due to eosinophilic gastritis",
#     "Umbilical hemorrhage after birth",
#     "Gastric hemorrhage due to atrophic gastritis",
#     "Subarachnoid hemorrhage from vertebral artery",
#     "Gastric hemorrhage due to angiodysplasia of stomach"
#   ],
#   "unclassified": [
#     "Systemic lupus erythematosus encephalitis",
#     "Hemangiopericytoma",
#     "Right atrial dilatation",
#     "Renal hypertension complicating pregnancy, childbirth and the puerperium - not delivered",
#     "Induced termination of pregnancy complicated by cardiac arrest",
#     "Cardiac arrest due to incomplete miscarriage",
#     "Cardiac arrest due to failed attempted abortion",
#     "Telangiectasia of skin of face"
#   ]
# }

# %%
import json
import glob
import os

def diagnose_non_list_values(directory="."):
    pattern = os.path.join(directory, "CV_Grouping_chunk_*.json")
    json_files = glob.glob(pattern)
    
    for fpath in json_files:
        with open(fpath, 'r', encoding='utf-8') as f:
            data = json.load(f)
            for key, value in data.items():
                # Check if the value is not a list
                if not isinstance(value, list):
                    print(f"File: {fpath}")
                    print(f"Key: '{key}' contains a {type(value).__name__} instead of a list.")
                    print(f"Value: {value}")
                    print("---")
                    
# Run the diagnostic function
diagnose_non_list_values()

# %%
# Specify the output file name
output_file = "merged_CV_Grouping.json"

# Write the merged dictionary to a JSON file
with open(output_file, 'w', encoding='utf-8') as f:
    json.dump(all_data, f, indent=2, ensure_ascii=False)

# %% [markdown]
# # extract relationships

# %%
with open("merged_CV_Grouping.json") as json_file:
    json_data = json.load(json_file)
    # print(json_data)

# %%
# Load data from the merged JSON file
with open("merged_CV_Grouping.json", "r", encoding="utf-8") as f:
    data = json.load(f)

# Convert the dictionary items into a list of tuples and create a DataFrame
gpt_groupings = pd.DataFrame(data.items(), columns=["ancestor_concept_name", "group_members"])

# %%
gpt_groupings
# Out:
#                                 ancestor_concept_name  \
# 0                                   vascular disorder
# 1                                          vasculitis
# 2                                      venous varices
# 3                                               other
# 4            chronic disease of cardiovascular system
# 5   congenital anomaly of cardiovascular structure...
# 6         congenital anomaly of cardiovascular system
# 7                        congenital vascular disorder
# 8                                          thrombosis
# 9                          thrombosis of blood vessel
# 10                        vascular disease of abdomen
# 11                                           embolism
# 12                               heart valve disorder
# 13             acute disease of cardiovascular system
# 14                                           aneurysm
# 15                                 cardiac arrhythmia
# 16                              cardiovascular injury
# 17                             injury of blood vessel
# 18                                 myocardial disease
# 19                         hemorrhage of blood vessel
# 20                                       unclassified
#
#                                         group_members
# 0   [Vascular hemostatic disease, Aortic thromboem...
# 1   [Retinal vasculitis, Necrotizing vasculitis, C...
# 2   [Varicose veins of lower extremity with inflam...
# 3   [Multi-infarct dementia, Postcardiotomy syndro...
# 4   [Chronic congestive heart failure, Systolic hy...
# 5   [Congenital anomaly of vena cava, Congenital a...
# 6   [Hypoplasia of right heart, Right hypoplastic ...
# 7   [Arteriovenous malformation of limb, Spinal ar...
# 8   [Thrombotic microangiopathy, Thrombus of cardi...
# 9   [Thrombosis of iliac artery, Thrombosis of abd...
# 10  [Dissection of abdominal aorta, Atherosclerosi...
# 11  [Complete miscarriage with embolism, Failed at...
# 12  [Tricuspid valve prolapse, Rheumatic heart val...
# 13  [Cardioembolic stroke, Cerebellar stroke, Sudd...
# 14  [Aneurysm of femoral artery, Common iliac aneu...
# 15  [Ventricular tachycardia, polymorphic, Ectopic...
# 16  [Contusion to heart with open wound into thora...
# 17  [Compression of vein, Injury of external carot...
# 18  [Dilated cardiomyopathy secondary to alcohol, ...
# 19  [Arterial hemorrhage, Esophageal varices assoc...
# 20  [Systemic lupus erythematosus encephalitis, He...

# %%
# Extract all lists from the 'group_members' column and flatten them into one list
all_grouped_terms = [item for sublist in gpt_groupings['group_members'] for item in sublist]

len(set(all_grouped_terms))
# Out:
# 1516

# %%
abc = [i.lower() for i in all_grouped_terms]
bcd = [i.lower() for i in full_terms]

len(set(abc).intersection(set(bcd)))
# Out:
# 1513

# %%
len(full_terms)
# Out:
# 1533

# %%
# drop rows 
gpt_groupings_final = gpt_groupings[gpt_groupings['ancestor_concept_name'].isin(ancestors_list)]

# Extract all lists from the 'group_members' column and flatten them into one list
filtered_grouped_terms = [item for sublist in gpt_groupings_final['group_members'] for item in sublist]

len(set(filtered_grouped_terms))
# Out:
# 1220

# %%
# number of categories in the final filtered df
len(gpt_groupings_final['ancestor_concept_name'].unique())
# Out:
# 19

# %%
abc = [i.lower() for i in filtered_grouped_terms]
bcd = [i.lower() for i in full_terms]

len(set(abc).intersection(set(bcd)))
# Out:
# 1218

# %%
valid_terms = set(t.lower() for t in full_terms)

len(set(abc).intersection(set(bcd)))

# %% [markdown]
# # Evaluation

# %%
# get gold standard groups

gold_standard = pd.read_csv("concept_subsumption_CVsubset.csv")

# Convert terms to lowercase if you want to avoid case sensitivity:
gold_standard['ancestor_concept_name'] = gold_standard['ancestor_concept_name'].str.lower()
gold_standard['descendant_concept_name'] = gold_standard['descendant_concept_name'].str.lower()

# filter gold_standard by only terms in my full list
valid_terms = set(t.lower() for t in full_terms)

# Filter rows where both ancestor and descendant are in valid_terms
filtered_df = gold_standard[
    gold_standard['ancestor_concept_name'].isin(valid_terms) & 
    gold_standard['descendant_concept_name'].isin(valid_terms)
]

# %%
filtered_df.head()
# Out:
#     descendant_concept_id                            descendant_concept_name  \
# 0                   22340                esophageal varices without bleeding
# 15                4111998  esophageal varices associated with another dis...
# 16                  22340                esophageal varices without bleeding
# 17                  28779                        bleeding esophageal varices
# 18                  24966                                 esophageal varices
#
#     ancestor_concept_id                ancestor_concept_name  \
# 0                 22340  esophageal varices without bleeding
# 15                24966                   esophageal varices
# 16                24966                   esophageal varices
# 17                24966                   esophageal varices
# 18                24966                   esophageal varices
#
#     min_levels_of_separation
# 0                          0
# 15                         1
# 16                         1
# 17                         1
# 18                         0

# %%
# Choose the level of separation that will define your groups
N = 5  # or 2, 3, etc., depending on how you want to slice the hierarchy

# 1. Filter for desired level
level_df = filtered_df[filtered_df['min_levels_of_separation'] == N].copy()

# 2. (Optional) Identify leaves if you want only leaf-level descendants:
all_ancestors = set(level_df['ancestor_concept_name'].unique())
all_descendants = set(level_df['descendant_concept_name'].unique())
leaf_terms = all_descendants - all_ancestors

# If you only want leaf descendants:
level_df = level_df[level_df['descendant_concept_name'].isin(leaf_terms)]

# 3. Group by ancestor to form groups
gold_levels = level_df.groupby('ancestor_concept_name')['descendant_concept_name'].apply(list).reset_index(name='group_members')

# %%
# 'grouped' now has two columns:
# 'ancestor' and 'group_members' (a list of descendants grouped under that ancestor)
gold_levels.head()
# Out:
#                       ancestor_concept_name  \
# 0    acute disease of cardiovascular system
# 1                                  aneurysm
# 2                        cardiac arrhythmia
# 3                     cardiovascular injury
# 4  chronic disease of cardiovascular system
#
#                                        group_members
# 0  [acute st segment elevation myocardial infarct...
# 1  [carotid artery aneurysm, aneurysm of poplitea...
# 2  [bifascicular block, right bundle branch block...
# 3  [injury of radial artery at wrist and hand lev...
# 4  [acute on chronic combined systolic and diasto...

# %%
gold_levels["ancestor_concept_name"].unique()
# Out:
# array(['acute disease of cardiovascular system', 'aneurysm',
#        'cardiac arrhythmia', 'cardiovascular injury',
#        'chronic disease of cardiovascular system',
#        'congenital anomaly of cardiovascular structure of trunk',
#        'congenital anomaly of cardiovascular system',
#        'congenital vascular disorder', 'embolism', 'heart valve disorder',
#        'hemorrhage of blood vessel', 'injury of blood vessel',
#        'myocardial disease', 'thrombosis', 'thrombosis of blood vessel',
#        'vascular disease of abdomen', 'vascular disorder', 'vasculitis',
#        'venous varices'], dtype=object)

# %%
ancestor_groups = gold_levels["ancestor_concept_name"].unique()

# %%
len(grouped["ancestor_concept_name"].unique())
# Out:
# 19

# %%
# filter filter_df by only ancestor concepts in the ancester_groups

filtered_df_2 = filtered_df[
    filtered_df['ancestor_concept_name'].isin(ancestor_groups)
]

# %%
filtered_df_2
# Out:
#        descendant_concept_id                      descendant_concept_name  \
# 2070                 4263510       congenital stenosis of tricuspid valve
# 2071                 4174077         myocardial bridge of coronary artery
# 2072                 4035467  congenital insufficiency of pulmonary valve
# 2073                 4085405                 congenital arterial aneurysm
# 2074                 4035494                      congenital phlebectasia
# ...                      ...                                          ...
# 96890                 315643                              tachyarrhythmia
# 96891                 441872             supraventricular premature beats
# 96892                 443522                         neonatal bradycardia
# 96893                 320744              complete atrioventricular block
# 96894                 317302                       sinus node dysfunction
#
#        ancestor_concept_id                        ancestor_concept_name  \
# 2070                141124  congenital anomaly of cardiovascular system
# 2071                141124  congenital anomaly of cardiovascular system
# 2072                141124  congenital anomaly of cardiovascular system
# 2073                141124  congenital anomaly of cardiovascular system
# 2074                141124  congenital anomaly of cardiovascular system
# ...                    ...                                          ...
# 96890             44784217                           cardiac arrhythmia
# 96891             44784217                           cardiac arrhythmia
# 96892             44784217                           cardiac arrhythmia
# 96893             44784217                           cardiac arrhythmia
# 96894             44784217                           cardiac arrhythmia
#
#        min_levels_of_separation
# 2070                          5
# 2071                          5
# 2072                          5
# 2073                          3
# 2074                          3
# ...                         ...
# 96890                         1
# 96891                         2
# 96892                         2
# 96893                         4
# 96894                         3
#
# [2712 rows x 5 columns]

# %%
gold_grouped = filtered_df_2.groupby('ancestor_concept_name')['descendant_concept_name'].apply(list).reset_index(name='group_members')

# %%
gold_grouped
# Out:
#                                 ancestor_concept_name  \
# 0              acute disease of cardiovascular system
# 1                                            aneurysm
# 2                                  cardiac arrhythmia
# 3                               cardiovascular injury
# 4            chronic disease of cardiovascular system
# 5   congenital anomaly of cardiovascular structure...
# 6         congenital anomaly of cardiovascular system
# 7                        congenital vascular disorder
# 8                                            embolism
# 9                                heart valve disorder
# 10                         hemorrhage of blood vessel
# 11                             injury of blood vessel
# 12                                 myocardial disease
# 13                                         thrombosis
# 14                         thrombosis of blood vessel
# 15                        vascular disease of abdomen
# 16                                  vascular disorder
# 17                                         vasculitis
# 18                                     venous varices
#
#                                         group_members
# 0   [acute myocardial infarction due to right coro...
# 1   [aneurysm of descending aorta, ruptured aneury...
# 2   [cardiac arrest during surgery, premature atri...
# 3   [injury of blood vessels at ankle and foot lev...
# 4   [chronic hypotension, chronic ischemic heart d...
# 5   [right ventricular outflow tract obstruction, ...
# 6   [congenital stenosis of tricuspid valve, myoca...
# 7   [patent ductus arteriosus, congenital anomaly ...
# 8   [cholesterol embolus syndrome, miscarriage com...
# 9   [congenital stenosis of mitral valve, mitral v...
# 10  [gastric hemorrhage due to eosinophilic gastri...
# 11  [injury of brachial artery, injury of pulmonar...
# 12  [av-junctional (nodal) bradycardia, subsequent...
# 13  [thromboangiitis obliterans, obstetric blood-c...
# 14  [superficial thrombophlebitis, thrombosis of r...
# 15  [injury of abdominal aorta, injury of ovarian ...
# 16  [phlebitis of portal vein, associated pulmonar...
# 17  [polyarteritis, cogan's syndrome, capillaritis...
# 18  [trunk varices, varicocele, bleeding gastric v...

# %% [markdown]
# # code for precision and recall

# %%
# 1. Merge on ancestor_concept_name
merged = pd.merge(
    gpt_groupings_final, 
    gold_grouped, 
    on="ancestor_concept_name", 
    suffixes=("_pred", "_gold")
)

merged
# Out:
#                                 ancestor_concept_name  \
# 0                                   vascular disorder
# 1                                          vasculitis
# 2                                      venous varices
# 3            chronic disease of cardiovascular system
# 4   congenital anomaly of cardiovascular structure...
# 5         congenital anomaly of cardiovascular system
# 6                        congenital vascular disorder
# 7                                          thrombosis
# 8                          thrombosis of blood vessel
# 9                         vascular disease of abdomen
# 10                                           embolism
# 11                               heart valve disorder
# 12             acute disease of cardiovascular system
# 13                                           aneurysm
# 14                                 cardiac arrhythmia
# 15                              cardiovascular injury
# 16                             injury of blood vessel
# 17                                 myocardial disease
# 18                         hemorrhage of blood vessel
#
#                                    group_members_pred  \
# 0   [Vascular hemostatic disease, Aortic thromboem...
# 1   [Retinal vasculitis, Necrotizing vasculitis, C...
# 2   [Varicose veins of lower extremity with inflam...
# 3   [Chronic congestive heart failure, Systolic hy...
# 4   [Congenital anomaly of vena cava, Congenital a...
# 5   [Hypoplasia of right heart, Right hypoplastic ...
# 6   [Arteriovenous malformation of limb, Spinal ar...
# 7   [Thrombotic microangiopathy, Thrombus of cardi...
# 8   [Thrombosis of iliac artery, Thrombosis of abd...
# 9   [Dissection of abdominal aorta, Atherosclerosi...
# 10  [Complete miscarriage with embolism, Failed at...
# 11  [Tricuspid valve prolapse, Rheumatic heart val...
# 12  [Cardioembolic stroke, Cerebellar stroke, Sudd...
# 13  [Aneurysm of femoral artery, Common iliac aneu...
# 14  [Ventricular tachycardia, polymorphic, Ectopic...
# 15  [Contusion to heart with open wound into thora...
# 16  [Compression of vein, Injury of external carot...
# 17  [Dilated cardiomyopathy secondary to alcohol, ...
# 18  [Arterial hemorrhage, Esophageal varices assoc...
#
#                                    group_members_gold
# 0   [phlebitis of portal vein, associated pulmonar...
# 1   [polyarteritis, cogan's syndrome, capillaritis...
# 2   [trunk varices, varicocele, bleeding gastric v...
# 3   [chronic hypotension, chronic ischemic heart d...
# 4   [right ventricular outflow tract obstruction, ...
# 5   [congenital stenosis of tricuspid valve, myoca...
# 6   [patent ductus arteriosus, congenital anomaly ...
# 7   [thromboangiitis obliterans, obstetric blood-c...
# 8   [superficial thrombophlebitis, thrombosis of r...
# 9   [injury of abdominal aorta, injury of ovarian ...
# 10  [cholesterol embolus syndrome, miscarriage com...
# 11  [congenital stenosis of mitral valve, mitral v...
# 12  [acute myocardial infarction due to right coro...
# 13  [aneurysm of descending aorta, ruptured aneury...
# 14  [cardiac arrest during surgery, premature atri...
# 15  [injury of blood vessels at ankle and foot lev...
# 16  [injury of brachial artery, injury of pulmonar...
# 17  [av-junctional (nodal) bradycardia, subsequent...
# 18  [gastric hemorrhage due to eosinophilic gastri...

# %%
# 2. Define a function to calculate precision and recall

valid_terms = set(t.lower() for t in full_terms)

def calculate_metrics(row):
    
    pred_set = {member.lower() for member in row["group_members_pred"] if member.lower() in valid_terms}
    gold_set = {member.lower() for member in row["group_members_gold"]}
    
    TP = pred_set.intersection(gold_set)
    FP = pred_set.difference(gold_set)
    FN = gold_set.difference(pred_set)
    
    precision = len(TP) / (len(TP) + len(FP)) if (len(TP) + len(FP)) > 0 else 0
    recall = len(TP) / (len(TP) + len(FN)) if (len(TP) + len(FN)) > 0 else 0
    
    return pd.Series([precision, recall])

# 3. Apply the function to each row
merged[["precision", "recall"]] = merged.apply(calculate_metrics, axis=1)

# Now merged has columns: ancestor_concept_name, group_members_pred, group_members_gold, precision, recall
print(merged[["ancestor_concept_name", "precision", "recall"]])
# Out:
#                                 ancestor_concept_name  precision    recall
# 0                                   vascular disorder   0.842105  0.155340
# 1                                          vasculitis   0.800000  0.388889
# 2                                      venous varices   0.750000  0.714286
# 3            chronic disease of cardiovascular system   0.307692  0.631579
# 4   congenital anomaly of cardiovascular structure...   0.636364  0.328125
# 5         congenital anomaly of cardiovascular system   0.582090  0.433333
# 6                        congenital vascular disorder   0.600000  0.339623
# 7                                          thrombosis   0.893333  0.549180
# 8                          thrombosis of blood vessel   0.634615  0.282051
# 9                         vascular disease of abdomen   0.822222  0.243421
# 10                                           embolism   0.982143  0.833333
# 11                               heart valve disorder   0.924731  0.716667
# 12             acute disease of cardiovascular system   0.508197  0.681319
# 13                                           aneurysm   0.864865  0.969697
# 14                                 cardiac arrhythmia   0.920455  0.778846
# 15                              cardiovascular injury   0.847458  0.373134
# 16                             injury of blood vessel   0.935484  0.731092
# 17                                 myocardial disease   0.679245  0.330275
# 18                         hemorrhage of blood vessel   0.689655  0.400000

# %%
merged
# Out:
#                                 ancestor_concept_name  \
# 0                                   vascular disorder
# 1                                          vasculitis
# 2                                      venous varices
# 3            chronic disease of cardiovascular system
# 4   congenital anomaly of cardiovascular structure...
# 5         congenital anomaly of cardiovascular system
# 6                        congenital vascular disorder
# 7                                          thrombosis
# 8                          thrombosis of blood vessel
# 9                         vascular disease of abdomen
# 10                                           embolism
# 11                               heart valve disorder
# 12             acute disease of cardiovascular system
# 13                                           aneurysm
# 14                                 cardiac arrhythmia
# 15                              cardiovascular injury
# 16                             injury of blood vessel
# 17                                 myocardial disease
# 18                         hemorrhage of blood vessel
#
#                                    group_members_pred  \
# 0   [Vascular hemostatic disease, Aortic thromboem...
# 1   [Retinal vasculitis, Necrotizing vasculitis, C...
# 2   [Varicose veins of lower extremity with inflam...
# 3   [Chronic congestive heart failure, Systolic hy...
# 4   [Congenital anomaly of vena cava, Congenital a...
# 5   [Hypoplasia of right heart, Right hypoplastic ...
# 6   [Arteriovenous malformation of limb, Spinal ar...
# 7   [Thrombotic microangiopathy, Thrombus of cardi...
# 8   [Thrombosis of iliac artery, Thrombosis of abd...
# 9   [Dissection of abdominal aorta, Atherosclerosi...
# 10  [Complete miscarriage with embolism, Failed at...
# 11  [Tricuspid valve prolapse, Rheumatic heart val...
# 12  [Cardioembolic stroke, Cerebellar stroke, Sudd...
# 13  [Aneurysm of femoral artery, Common iliac aneu...
# 14  [Ventricular tachycardia, polymorphic, Ectopic...
# 15  [Contusion to heart with open wound into thora...
# 16  [Compression of vein, Injury of external carot...
# 17  [Dilated cardiomyopathy secondary to alcohol, ...
# 18  [Arterial hemorrhage, Esophageal varices assoc...
#
#                                    group_members_gold  precision    recall
# 0   [atherosclerosis of right carotid artery, acut...   0.052632  0.106667
# 1          [syphilitic aortitis, syphilitic aortitis]   0.028571  1.000000
# 2   [varicose veins of lower extremity with ulcer ...   0.050000  1.000000
# 3   [acute on chronic combined systolic and diasto...   0.000000  0.000000
# 4   [right ventricular outflow tract obstruction, ...   0.060606  1.000000
# 5   [congenital stenosis of tricuspid valve, myoca...   0.119403  0.500000
# 6   [congenital anomaly of coronary artery, total ...   0.000000  0.000000
# 7   [embolism and thrombosis of the thoracic aorta...   0.226667  0.435897
# 8   [cerebral venous thrombosis in the puerperium,...   0.019231  0.333333
# 9   [acute gastric ulcer with hemorrhage but witho...   0.088889  0.400000
# 10  [obstetric pyemic and septic pulmonary embolis...   0.017857  0.500000
# 11  [ebstein's anomaly of common atrioventricular ...   0.000000  0.000000
# 12  [acute st segment elevation myocardial infarct...   0.040984  1.000000
# 13  [carotid artery aneurysm, aneurysm of poplitea...   0.162162  0.857143
# 14  [bifascicular block, right bundle branch block...   0.034091  0.600000
# 15  [injury of radial artery at wrist and hand lev...   0.135593  0.296296
# 16  [injury of external carotid artery, injury of ...   0.021505  1.000000
# 17  [dilated cardiomyopathy secondary to drug, dil...   0.037736  0.666667
# 18  [dissection of abdominal aorta, dissection of ...   0.000000  0.000000

# %%
merged.to_csv("finalEval_GPTgroups.csv", index=False)
